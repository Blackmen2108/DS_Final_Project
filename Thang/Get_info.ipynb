# %%
def info_process(information):
    label = []
    detail = []
    information = information[0].split('\n')
    del information[-2:]

    for i in range(len(information)):
        information[i] = information[i].split(': ', 1)

    for i in range(len(information)):
        label.append(information[i][0])
        detail.append(information[i][1])
    return label, detail

# %%
from requests_html import HTMLSession, HTML
import requests
from selenium import webdriver
import time

session = HTMLSession()
labels_of_each_product = []
details_of_each_product = []
rf = open('price_links.txt', 'r')

for i in range(500):
    information = []
    link = rf.readline()
    r = session.get(link.strip())
    
    infos = r.html.find('#model-brief-specifications')
    for info in infos:
        information.append(info.text)

    label, detail = info_process(information)
    labels_of_each_product.append(label)
    details_of_each_product.append(detail)
    
    print(label)
    print(detail)
    print("\n")
    
    session.close() 
    session = HTMLSession()
    time.sleep(1)
# Out:
# ['SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['Qualcomm Snapdragon 636', '4x 1.8 GHz Kryo 260, 4x 1.6 GHz Kryo 260, Cores: 8', 'Qualcomm Adreno 509', '4 GB, 6 GB, 1333 MHz', '64 GB', 'microSD, microSDHC, microSDXC', '6.18 in, IPS, 1080 x 2246 pixels, 24 bit', '5000 mAh, Li-Polymer', 'Android 8.1 Oreo', '4608 x 3456 pixels, 3840 x 2160 pixels, 30 fps', 'Nano-SIM', 'b, g, n, Wi-Fi Hotspot, Wi-Fi Direct', '2.0, Micro USB', '4.2', 'GPS, A-GPS, GLONASS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['70.5 x 147.7 x 8.6 mm', '144 g', 'Qualcomm Snapdragon 425 MSM8917', 'ARM Cortex-A53, 1400 MHz, Cores: 4', 'Qualcomm Adreno 308, 500 MHz', '2 GB, 3 GB, 667 MHz', '16 GB, 32 GB', 'microSD, microSDHC, microSDXC', '5.45 in, IPS, 720 x 1440 pixels, 24 bit', '3200 mAh, Li-Polymer', 'Android 8.1 Oreo', '4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps', 'Nano-SIM', 'b, g, n, Wi-Fi Hotspot, Wi-Fi Direct', '2.0, Micro USB', '4.2', 'GPS, A-GPS, GLONASS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['76 x 155 x 8.5 mm', '170 g', 'Qualcomm Snapdragon 626 MSM8953 Pro', 'ARM Cortex-A53, 2200 MHz, Cores: 8', 'Qualcomm Adreno 506', '3 GB, 4 GB, 800 MHz', '32 GB, 64 GB', 'microSD, microSDHC, microSDXC', '5.5 in, IPS, 1080 x 1920 pixels, 24 bit', '4000 mAh, Li-Polymer', 'Android 7.1.2 Nougat', '4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps', 'Nano-SIM, Nano-SIM / microSD', 'b, g, n, Wi-Fi Hotspot, Wi-Fi Direct', '2.0, Micro USB', '4.2', 'GPS, A-GPS, GLONASS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['76 x 152 x 8.25 mm', '156 g', 'Qualcomm Snapdragon 653 MSM8976 Pro', '4x 1.95 GHz ARM Cortex-A72, 4x 1.44 GHz ARM Cortex-A53, Cores: 8', 'Qualcomm Adreno 510', '6 GB, 933 MHz', '32 GB, 64 GB', 'microSD, microSDHC, microSDXC', '5.5 in, IPS, 1080 x 1920 pixels, 24 bit', '4000 mAh, Li-Polymer', '360 2.0 (Android 6.0 Marshmallow)', '4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps', 'Nano-SIM, Nano-SIM / microSD', 'a, b, g, n, n 5GHz, ac, Dual band, Wi-Fi Hotspot, Wi-Fi Direct', '2.0, Micro USB', '4.2', 'GPS, A-GPS, GLONASS, BeiDou']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['80 x 156.5 x 8.3 mm', '175 g', 'Qualcomm Snapdragon 820 MSM8996', '2x 2.15 GHz Kryo, 2x 1.6 GHz Kryo, Cores: 4', 'Qualcomm Adreno 530, 624 MHz', '4 GB, 6 GB, 1866 MHz', '128 GB', 'microSD, microSDHC, microSDXC', '6 in, Super AMOLED, 1080 x 1920 pixels, 24 bit', '3700 mAh, Li-Ion', '360 2.0 (Android 6.0 Marshmallow)', '4160 x 3120 pixels, 3840 x 2160 pixels, 30 fps', 'Nano-SIM, Nano-SIM / microSD', 'a, b, g, n, n 5GHz, Dual band, Wi-Fi Hotspot, Wi-Fi Direct', '2.0, USB Type-C', '4.1', 'GPS, A-GPS, GLONASS, BeiDou']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['74 x 149.5 x 8.5 mm', '164 g', 'Qualcomm Snapdragon 652 MSM8976', '4x 1.8 GHz ARM Cortex-A72, 4x 1.4 GHz ARM Cortex-A53, Cores: 8', 'Qualcomm Adreno 510, 550 MHz', '4 GB, 933 MHz', '128 GB', 'microSD, microSDHC, microSDXC', '5.5 in, Super AMOLED, 1080 x 1920 pixels, 24 bit', '3200 mAh, Li-Ion', '360 2.0 (Android 6.0 Marshmallow)', '4160 x 3120 pixels, 3840 x 2160 pixels, 30 fps', 'Nano-SIM, Nano-SIM / microSD', 'a, b, g, n, n 5GHz, Dual band, Wi-Fi Hotspot, Wi-Fi Direct', '2.0, USB Type-C', '4.1', 'GPS, A-GPS, GLONASS, BeiDou']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['74.6 x 151.3 x 8.35 mm', '169 g', 'MediaTek Helio X20 (MT6797M)', '2x 2.0 GHz ARM Cortex-A72, 4x 1.85 GHz ARM Cortex-A53, 4x 1.4 GHz ARM Cortex-A53', 'ARM Mali-T880 MP4, 780 MHz, Cores: 4', '4 GB, 800 MHz', '32 GB', 'microSD, microSDHC, microSDXC', '5.5 in, IPS, 1080 x 1920 pixels, 24 bit', '5000 mAh, Li-Polymer', '360 2.0 (Android 6.0 Marshmallow)', '5312 x 2988 pixels, 1920 x 1080 pixels, 30 fps', 'Nano-SIM, Nano-SIM / microSD', 'a, b, g, n, n 5GHz, ac, Dual band, Wi-Fi Hotspot, Wi-Fi Direct', '2.0, Micro USB', '4.1', 'GPS, A-GPS, GLONASS, BeiDou']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['75.7 x 149 x 8.3 mm', '140 g', 'MediaTek Helio X20 (MT6797M)', '2x 2.0 GHz ARM Cortex-A72, 4x 1.85 GHz ARM Cortex-A53, 4x 1.4 GHz ARM Cortex-A53', 'ARM Mali-T880 MP4, 780 MHz, Cores: 4', '4 GB, 800 MHz', '32 GB', 'microSD, microSDHC, microSDXC', '5.5 in, IPS, 1080 x 1920 pixels, 24 bit', '3080 mAh, Li-Polymer', '360 (Android 6.0 Marshmallow)', '4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps', 'Nano-SIM, Nano-SIM / microSD', 'a, b, g, n, n 5GHz, ac, Dual band, Wi-Fi Hotspot, Wi-Fi Direct', '2.0, Micro USB', '4.0', 'GPS, A-GPS, GLONASS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'Wi-Fi', 'USB', 'Bluetooth']
# ['253.9 x 170 x 8.3 mm', '560 g', 'MediaTek MT8167A', 'ARM Cortex-A53, 1500 MHz, Cores: 4', 'PowerVR GE8300', '2 GB', '32 GB', 'microSD, microSDHC, microSDXC', '10.1 in, IPS, 1920 x 1200 pixels, 24 bit', '6100 mAh, Li-Polymer', 'Android 7.0 Nougat', '2624 x 1968 pixels, 1920 x 1080 pixels, 30 fps', 'a, b, g, n, ac', '2.0, Micro USB', '4.1']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'Wi-Fi', 'USB', 'Bluetooth']
# ['238.2 x 172.2 x 9.98 mm', '549 g', 'Rockchip RK3399', '2x 2.0 GHz ARM Cortex-A72, 4x 1.5 GHz ARM Cortex-A53, Cores: 6', 'ARM Mali-T860 MP4, Cores: 4', '4 GB, 1866 MHz', '32 GB', 'microSD, microSDHC, microSDXC', '9.7 in, IPS, 2048 x 1536 pixels, 24 bit', 'Li-Polymer', 'Chrome', '2624 x 1968 pixels, 1920 x 1080 pixels, 30 fps', 'a, b, g, n, ac', 'USB Type-C', '4.1']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['76.8 x 156.6 x 8.5 mm', '150 g', 'Qualcomm Snapdragon 808 MSM8992', '2x 1.8 GHz ARM Cortex-A57, 4x 1.44 GHz ARM Cortex-A53, Cores: 6', 'Qualcomm Adreno 418, 600 MHz', '3 GB, 933 MHz', '32 GB', 'microSD, microSDHC, microSDXC', '5.5 in, AMOLED, 1080 x 1920 pixels, 24 bit', '2800 mAh, Li-Polymer', 'Microsoft Windows 10 Continuum', '5344 x 4016 pixels, 3840 x 2160 pixels, 30 fps', 'Nano-SIM, Nano-SIM / microSD', 'a, b, g, n, ac, Dual band, Wi-Fi Hotspot, Wi-Fi Direct', '2.0, USB Type-C', '4.1', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['66.7 x 136 x 9.9 mm', '145 g', 'MediaTek MT6732M', 'ARM Cortex-A53, 1300 MHz, Cores: 4', 'ARM Mali-T760 MP2, 500 MHz, Cores: 2', '1 GB, 800 MHz', '8 GB', 'microSD, microSDHC, microSDXC', '4.5 in, IPS, 540 x 960 pixels, 24 bit', '2000 mAh, Li-Polymer', 'Android 4.4.4 KitKat', '2592 x 1944 pixels, 1920 x 1080 pixels, 30 fps', 'Micro-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['62.5 x 110 x 12.3 mm', '110 g', 'Qualcomm Snapdragon S1 MSM7227A', 'ARM Cortex-A5, 1000 MHz, Cores: 1', 'Qualcomm Adreno 200', '512 MB, 200 MHz', '4 GB', 'microSD, microSDHC', '3.5 in, TFT, 320 x 480 pixels, 18 bit', '1300 mAh, Li-Ion', 'Android 4.1.1 Jelly Bean', '2048 x 1536 pixels', 'Mini-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '3.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['81.4 x 168 x 12.6 mm', '251 g', 'Qualcomm Snapdragon 450', 'ARM Cortex-A53, 1800 MHz, Cores: 8', 'Qualcomm Adreno 506', '3 GB, 4 GB, 933 MHz', '32 GB, 64 GB', 'microSD, microSDHC, microSDXC', '5.99 in, IPS, 1080 x 2160 pixels, 24 bit', '5400 mAh, Li-Polymer', 'Android 8.1 Oreo', '4000 x 3000 pixels, 1920 x 1080 pixels, 30 fps', 'Nano-SIM / microSD, Nano-SIM', 'b, g, n, n 5GHz, Dual band, Wi-Fi Hotspot, Wi-Fi Direct', '2.0, USB Type-C', '4.0', 'GPS, A-GPS, GLONASS, BeiDou']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['81.5 x 167.5 x 10.5 mm', '216 g', 'Qualcomm Snapdragon 845', '4x 2.8 GHz Kryo 385, 4x 1.8 GHz Kryo 385, Cores: 8', 'Qualcomm Adreno 630, 710 MHz', '6 GB, 8 GB, 1866 MHz', '64 GB, 128 GB, 256 GB', 'microSD, microSDHC, microSDXC', '5.99 in, TFT, 1080 x 2160 pixels, 24 bit', '4100 mAh, Li-Polymer', 'X OS 3.0 (Android 8.1 Oreo)', '4032 x 3024 pixels, 1920 x 1080 pixels, 30 fps', 'Nano-SIM / microSD, Nano-SIM', 'a, b, g, n, n 5GHz, ac, Dual band, Wi-Fi Hotspot, Wi-Fi Direct', '2.0, USB Type-C', '5.0', 'GPS, A-GPS, GLONASS, BeiDou']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['83.4 x 168.5 x 14 mm', '250 g', 'Qualcomm Snapdragon 653 MSM8976 Pro', '4x 1.95 GHz ARM Cortex-A72, 4x 1.44 GHz ARM Cortex-A53, Cores: 8', 'Qualcomm Adreno 510', '6 GB, 933 MHz', '64 GB', 'microSD, microSDHC, microSDXC', '5.5 in, AMOLED, 1080 x 1920 pixels, 24 bit', '6000 mAh, Li-Polymer', 'Android 7.1 Nougat', '4000 x 3000 pixels, 1920 x 1080 pixels, 30 fps', 'Nano-SIM / microSD, Nano-SIM', 'b, g, n, n 5GHz, Dual band, Wi-Fi Hotspot, Wi-Fi Direct', '2.0, USB Type-C', '4.0', 'GPS, A-GPS, GLONASS, BeiDou']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['75 x 155 x 13 mm', '189 g', 'Qualcomm Snapdragon 210 MSM8909', 'ARM Cortex-A7, 1100 MHz, Cores: 4', 'Qualcomm Adreno 304, 400 MHz', '2 GB, 533 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '5 in, TFT, 720 x 1280 pixels, 24 bit', '4000 mAh, Li-Polymer', 'Android 6.0 Marshmallow', '3264 x 2448 pixels, 1280 x 720 pixels, 30 fps', 'Micro-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['74 x 139 x 18 mm', '255 g', 'Qualcomm Snapdragon 210 MSM8909', 'ARM Cortex-A7, 1100 MHz, Cores: 4', 'Qualcomm Adreno 304, 400 MHz', '2 GB, 533 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '4 in, TFT, 480 x 800 pixels, 24 bit', '2930 mAh, Li-Polymer', 'Android 6.0 Marshmallow', '3264 x 2448 pixels, 1280 x 720 pixels, 30 fps', 'Micro-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['83 x 159 x 16 mm', '247 g', 'Qualcomm Snapdragon 410 MSM8916', 'ARM Cortex-A53, 1200 MHz, Cores: 4', 'Qualcomm Adreno 306, 400 MHz', '2 GB, 533 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '5 in, IPS, 720 x 1280 pixels, 24 bit', '4050 mAh, Li-Polymer', 'Android 7.0 Nougat', '3264 x 2448 pixels, 1280 x 720 pixels, 30 fps', 'Nano-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.0', 'GPS, A-GPS, GLONASS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['70 x 131 x 15 mm', '192 g', 'Qualcomm Snapdragon 210 MSM8909', 'ARM Cortex-A7, 1100 MHz, Cores: 4', 'Qualcomm Adreno 304, 400 MHz', '2 GB, 533 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '4 in, TFT, 480 x 800 pixels, 24 bit', '2600 mAh, Li-Polymer', 'Android 5.1 Lollipop', '3264 x 2448 pixels, 1280 x 720 pixels, 30 fps', 'Micro-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['83 x 158 x 16 mm', '245 g', 'Qualcomm Snapdragon 410 MSM8916', 'ARM Cortex-A53, 1200 MHz, Cores: 4', 'Qualcomm Adreno 306, 400 MHz', '3 GB, 533 MHz', '32 GB', 'microSD, microSDHC, microSDXC', '5 in, IPS, 720 x 1280 pixels, 24 bit', '4050 mAh, Li-Polymer', 'Android 7.0 Nougat', '4160 x 3120 pixels, 1280 x 720 pixels, 30 fps', 'Nano-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.0', 'GPS, A-GPS, GLONASS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['83.4 x 168.5 x 14 mm', '250 g', 'Qualcomm Snapdragon 653 MSM8976 Pro', '4x 1.95 GHz ARM Cortex-A72, 4x 1.44 GHz ARM Cortex-A53, Cores: 8', 'Qualcomm Adreno 510', '6 GB, 933 MHz', '64 GB, 128 GB', 'microSD, microSDHC, microSDXC', '5.5 in, AMOLED, 1080 x 1920 pixels, 24 bit', '6000 mAh, Li-Polymer', 'Android 7.1 Nougat', '4000 x 3000 pixels, 1920 x 1080 pixels, 30 fps', 'Nano-SIM / microSD, Nano-SIM', 'b, g, n, n 5GHz, Dual band, Wi-Fi Hotspot, Wi-Fi Direct', '2.0, USB Type-C', '4.0', 'GPS, A-GPS, GLONASS, BeiDou']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['83 x 159 x 16 mm', '247 g', 'Qualcomm Snapdragon 410 MSM8916', 'ARM Cortex-A53, 1200 MHz, Cores: 4', 'Qualcomm Adreno 306, 400 MHz', '3 GB, 4 GB, 533 MHz', '32 GB, 64 GB', 'microSD, microSDHC, microSDXC', '5 in, IPS, 720 x 1280 pixels, 24 bit', '4050 mAh, Li-Polymer', 'Android 7.0 Nougat', '4160 x 3120 pixels, 1280 x 720 pixels, 30 fps', 'Nano-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.0', 'GPS, A-GPS, GLONASS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['73.2 x 133.2 x 14.5 mm', '225 g', 'Qualcomm Snapdragon 210 MSM8909', 'ARM Cortex-A7, 1100 MHz, Cores: 4', 'Qualcomm Adreno 304, 400 MHz', '2 GB, 533 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '4 in, TFT, 480 x 800 pixels, 24 bit', '2600 mAh, Li-Polymer', 'Android 5.1.1 Lollipop', '3264 x 2448 pixels, 1280 x 720 pixels, 30 fps', 'Micro-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['78.7 x 163.5 x 11.88 mm', '210 g', 'Qualcomm Snapdragon 617 MSM8952', '4x 1.5 GHz ARM Cortex-A53, 4x 1.2 GHz ARM Cortex-A53, Cores: 8', 'Qualcomm Adreno 405', '4 GB, 933 MHz', '64 GB', 'microSD, microSDHC, microSDXC', '5.5 in, Super AMOLED, 1080 x 1920 pixels, 24 bit', '5400 mAh, Li-Polymer', 'X OS 1.0 (Android 5.1.1 Lollipop)', '4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps', 'Nano-SIM / microSD, Micro-SIM', 'b, g, n, n 5GHz, Dual band, Wi-Fi Hotspot, Wi-Fi Direct', '2.0, Micro USB', '4.0', 'GPS, A-GPS, GLONASS, BeiDou']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['75.8 x 164.8 x 8.39 mm', '178 g', 'MediaTek Helio P23 (MT6763V)', '4x 2.0 GHz ARM Cortex-A53, 4x 1.5 GHz ARM Cortex-A53, Cores: 8', 'ARM Mali-G71 MP2, 700 MHz, Cores: 2', '4 GB', '64 GB', 'microSD, microSDHC, microSDXC', '6.52 in, IPS, 720 x 1600 pixels, 24 bit', '4000 mAh, Li-Ion', 'Android 9.0 Pie', '4608 x 3456 pixels, 1920 x 1080 pixels, 30 fps', 'Nano-SIM / microSD, Nano-SIM', 'b, g, n, Wi-Fi Hotspot, Wi-Fi Direct', '2.0, Micro USB', '4.2', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['260 x 156.6 x 8.95 mm', '440 g', 'MediaTek MT8765B', 'ARM Cortex-A53, 1280 MHz, Cores: 4', '2 GB', '16 GB', 'microSD, microSDHC, microSDXC', '10 in, IPS, 1280 x 800 pixels, 24 bit', '4080 mAh, Li-Polymer', 'Android 9.0 Pie', '1600 x 1200 pixels, 1280 x 720 pixels, 30 fps', 'Nano-SIM', 'a, b, g, n, n 5GHz, Dual band, Wi-Fi Direct, Wi-Fi Display', '2.0, Micro USB', '4.2', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['65.7 x 137.6 x 9.8 mm', '134 g', 'MediaTek MT6739', 'ARM Cortex-A53, 1300 MHz, Cores: 4', 'PowerVR GE8100, 570 MHz', '1 GB, 667 MHz', '8 GB', 'microSD, microSDHC', '5 in, LCD, 480 x 960 pixels, 24 bit', '2000 mAh, Li-Polymer', 'Android 8.0 Oreo Go Edition', '2592 x 1944 pixels, 1920 x 1080 pixels, 30 fps', 'Nano-SIM', 'b, g, n, Wi-Fi Hotspot, Wi-Fi Direct, Wi-Fi Display', '2.0, Micro USB', '4.2', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['70.7 x 147.8 x 8.6 mm', '146 g', 'Unisoc SC9863A', '4x 1.6 GHz ARM Cortex-A55, 4x 1.2 GHz ARM Cortex-A55, Cores: 8', 'PowerVR GE8322', '3 GB', '32 GB', 'microSD, microSDHC, microSDXC', '5.5 in, IPS, 720 x 1440 pixels, 24 bit', '3060 mAh, Li-Polymer', 'Android 9.0 Pie', '4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps', 'Nano-SIM', 'b, g, n, Wi-Fi Hotspot, Wi-Fi Direct, Wi-Fi Display', '2.0, Micro USB', '4.2', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['68.8 x 146.35 x 8.3 mm', '130 g', 'MediaTek MT6739WW', 'ARM Cortex-A53, 1500 MHz, Cores: 4', 'PowerVR GE8100', '2 GB, 667 MHz', '32 GB', 'microSD, microSDHC, microSDXC', '5.5 in, IPS, 720 x 1440 pixels, 24 bit', '3000 mAh, Li-Polymer', 'Android 8.1 Oreo', '4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps', 'Nano-SIM', 'b, g, n, Wi-Fi Hotspot, Wi-Fi Direct, Wi-Fi Display', '2.0, Micro USB', '4.2', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['70.62 x 147.55 x 9.05 mm', '155 g', 'MediaTek MT6739', 'ARM Cortex-A53, 1300 MHz, Cores: 4', 'PowerVR GE8100, 570 MHz', '2 GB, 667 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '5.34 in, IPS, 480 x 960 pixels, 24 bit', '2460 mAh, Li-Polymer', 'Android 8.1 Oreo', '3264 x 2448 pixels, 1920 x 1080 pixels, 30 fps', 'Nano-SIM', 'b, g, n, Wi-Fi Hotspot, Wi-Fi Direct, Wi-Fi Display', '2.0, Micro USB', '4.2', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['69.6 x 148.1 x 9.4 mm', '152 g', 'MediaTek MT6739WM', 'ARM Cortex-A53, 1100 MHz, Cores: 4', 'PowerVR GE8100', '2 GB, 667 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '5.34 in, IPS, 480 x 960 pixels, 24 bit', '2460 mAh, Li-Polymer', 'Android 8.1 Oreo', '3264 x 2448 pixels, 1280 x 720 pixels, 30 fps', 'Nano-SIM', 'b, g, n, Wi-Fi Hotspot, Wi-Fi Direct, Wi-Fi Display', '2.0, Micro USB', '4.1', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['69.6 x 147.3 x 9.4 mm', '152 g', 'MediaTek MT6739WM', 'ARM Cortex-A53, 1100 MHz, Cores: 4', 'PowerVR GE8100', '2 GB, 667 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '5.34 in, IPS, 480 x 960 pixels, 24 bit', '2460 mAh, Li-Polymer', 'Android 8.1 Oreo', '3264 x 2448 pixels, 1280 x 720 pixels, 30 fps', 'Nano-SIM', 'b, g, n, Wi-Fi Hotspot, Wi-Fi Direct, Wi-Fi Display', '2.0, Micro USB', '4.1', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['71.9 x 142.5 x 9.4 mm', '134 g', 'MediaTek MT6739', 'ARM Cortex-A53, 1300 MHz, Cores: 4', 'PowerVR GE8100, 570 MHz', '2 GB, 667 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '5 in, IPS, 480 x 854 pixels, 24 bit', '2050 mAh, Li-Polymer', 'Android 8.1 Oreo', '2592 x 1944 pixels, 1280 x 720 pixels, 30 fps', 'Nano-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.1', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['75.8 x 162.1 x 8.6 mm', '175 g', 'MediaTek Helio P23 (MT6763T)', '4x 2.3 GHz ARM Cortex-A53, 4x 1.65 GHz ARM Cortex-A53, Cores: 8', 'ARM Mali-G71 MP2, 770 MHz, Cores: 2', '2 GB, 1600 MHz', '32 GB', 'microSD, microSDHC, microSDXC', '6 in, IPS, 1080 x 2160 pixels, 24 bit', '4000 mAh, Li-Polymer', 'Android 8.1 Oreo', '4000 x 3000 pixels, 1920 x 1080 pixels, 30 fps', 'Nano-SIM', 'a, b, g, n, n 5GHz, Dual band, Wi-Fi Hotspot, Wi-Fi Direct, Wi-Fi Display', '2.0, USB Type-C', '4.2', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['74.55 x 153.7 x 8.5 mm', '158 g', 'MediaTek Helio P22 (MT6762)', '4x 2.0 GHz ARM Cortex-A53, 4x 1.5 GHz ARM Cortex-A53, Cores: 8', 'PowerVR GE8320, 650 MHz', '3 GB, 933 MHz', '32 GB', 'microSD, microSDHC, microSDXC', '6.2 in, IPS, 720 x 1500 pixels, 24 bit', '4000 mAh, Li-Polymer', 'Android 8.1 Oreo', '4032 x 3024 pixels, 1920 x 1080 pixels, 30 fps', 'Micro-SIM', 'b, g, n, Wi-Fi Hotspot, Wi-Fi Direct', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['255 x 155 x 9.35 mm', '415 g', 'MediaTek MT8321', 'ARM Cortex-A7, 1300 MHz, Cores: 4', 'ARM Mali-400 MP2, 500 MHz, Cores: 2', '1 GB', '16 GB', 'microSD, microSDHC, microSDXC', '10.1 in, IPS, 1280 x 800 pixels, 24 bit', '4000 mAh, Li-Polymer', 'Android 8.1 Oreo', '2592 x 1944 pixels, 1280 x 720 pixels, 30 fps', 'b, g, n, Wi-Fi Hotspot, Wi-Fi Direct, Wi-Fi Display', '2.0, Micro USB', '4.2', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'Wi-Fi', 'USB', 'Bluetooth']
# ['189.5 x 111 x 9.15 mm', '245 g', 'MediaTek MT8321', 'ARM Cortex-A7, 1300 MHz, Cores: 4', 'ARM Mali-400 MP2, 500 MHz, Cores: 2', '1 GB', '8 GB', 'microSD, microSDHC, microSDXC', '7 in, TFT, 1024 x 600 pixels, 24 bit', '2580 mAh, Li-Polymer', 'Android 8.1 Oreo Go Edition', '2592 x 1944 pixels, 1280 x 720 pixels, 30 fps', 'b, g, n, Wi-Fi Hotspot, Wi-Fi Direct', '2.0, Micro USB', '4.2']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['70.6 x 146.9 x 9.2 mm', '156 g', 'MediaTek MT6580M', 'ARM Cortex-A7, 1300 MHz, Cores: 4', 'ARM Mali-400 MP2, 416 MHz, Cores: 2', '1 GB, 533 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '5.3 in, IPS, 480 x 960 pixels, 24 bit', '2460 mAh, Li-Polymer', 'Android 7.0 Nougat', '3264 x 2448 pixels, 1280 x 720 pixels, 30 fps', 'Nano-SIM', 'b, g, n, Wi-Fi Hotspot, Wi-Fi Direct', '2.0, Micro USB', '4.2', 'GPS, A-GPS']
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['70.6 x 147.5 x 9.1 mm', '151 g', 'MediaTek MT6739', 'ARM Cortex-A53, 1300 MHz, Cores: 4', 'PowerVR GE8100, 570 MHz', '1 GB, 2 GB, 667 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '5.3 in, IPS, 480 x 960 pixels, 24 bit', '2460 mAh, Li-Polymer', 'Android 8.1 Oreo Go Edition', '3264 x 2448 pixels, 1920 x 1080 pixels, 30 fps', 'Nano-SIM', 'b, g, n, Wi-Fi Hotspot, Wi-Fi Direct, Wi-Fi Display', '2.0, Micro USB', '4.2', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['71.6 x 153.5 x 8.5 mm', '144 g', 'MediaTek MT6739', 'ARM Cortex-A53, 1300 MHz, Cores: 4', 'PowerVR GE8100, 570 MHz', '3 GB, 667 MHz', '32 GB', 'microSD, microSDHC, microSDXC', '5.7 in, IPS, 720 x 1440 pixels, 24 bit', '3000 mAh, Li-Polymer', 'Android 7.1.1 Nougat', '4160 x 3120 pixels, 1920 x 1080 pixels, 24 fps', 'Nano-SIM, Nano-SIM / microSD', 'b, g, n, Wi-Fi Hotspot, Wi-Fi Direct, Wi-Fi Display', '2.0, Micro USB', '4.2', 'GPS, A-GPS, GLONASS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['68.8 x 147.1 x 8.45 mm', '145 g', 'MediaTek MT6739', 'ARM Cortex-A53, 1300 MHz, Cores: 4', 'PowerVR GE8100, 570 MHz', '2 GB, 667 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '5.5 in, IPS, 720 x 1440 pixels, 24 bit', '3000 mAh, Li-Polymer', 'Android 8.0 Oreo', '4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps', 'Nano-SIM', 'b, g, n, Wi-Fi Hotspot, Wi-Fi Direct, Wi-Fi Display', '2.0, Micro USB', '4.2', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['76 x 162 x 8.05 mm', '155 g', 'MediaTek MT8735A', 'ARM Cortex-A53, 1450 MHz, Cores: 4', 'ARM Mali-T720 MP2, Cores: 2', '2 GB, 3 GB, 640 MHz', '16 GB, 32 GB', 'microSD, microSDHC, microSDXC', '6 in, IPS, 1080 x 2160 pixels, 24 bit', '3000 mAh, Li-Polymer', 'Android 8.0 Oreo', '4032 x 3024 pixels, 1920 x 1080 pixels, 30 fps', 'Nano-SIM, Nano-SIM / microSD', 'a, b, g, n, n 5GHz, Dual band, Wi-Fi Hotspot, Wi-Fi Direct', '2.0, Micro USB', '4.2', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['71.88 x 141.5 x 9.9 mm', '157 g', 'Qualcomm Snapdragon 210 MSM8909', 'ARM Cortex-A7, 1100 MHz, Cores: 4', 'Qualcomm Adreno 304, 400 MHz', '2 GB, 533 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '5 in, IPS, 480 x 854 pixels, 24 bit', '2050 mAh, Li-Polymer', 'Android 7.0 Nougat', '2592 x 1944 pixels, 1280 x 720 pixels, 30 fps', 'Nano-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.1', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['76 x 161 x 7.9 mm', '169 g', 'MediaTek MT8321', 'ARM Cortex-A7, 1300 MHz, Cores: 4', 'ARM Mali-400 MP2, 500 MHz, Cores: 2', '1 GB', '16 GB', 'microSD, microSDHC, microSDXC', '6 in, IPS, 720 x 1440 pixels, 24 bit', '3000 mAh, Li-Polymer', 'Android 7.0 Nougat', '3264 x 2448 pixels, 1920 x 1080 pixels, 30 fps', 'Nano-SIM', 'b, g, n, Wi-Fi Hotspot, Wi-Fi Direct, Wi-Fi Display', '2.0, Micro USB', '4.2', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['71.88 x 141.5 x 9.91 mm', '157 g', 'Qualcomm Snapdragon 210 MSM8909', 'ARM Cortex-A7, 1100 MHz, Cores: 4', 'Qualcomm Adreno 304, 400 MHz', '2 GB, 533 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '5 in, IPS, 480 x 854 pixels, 24 bit', '2050 mAh, Li-Polymer', 'Android 7.0 Nougat', '2592 x 1944 pixels, 1280 x 720 pixels, 30 fps', 'Nano-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.1', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['71.9 x 148.1 x 7.62 mm', '147 g', 'MediaTek Helio P20 (MT6757)', '4x 2.3 GHz ARM Cortex-A53, 4x 1.6 GHz ARM Cortex-A53, Cores: 8', 'ARM Mali-T880 MP2, 900 MHz, Cores: 2', '2 GB, 1600 MHz', '32 GB', 'microSD, microSDHC, microSDXC', '5.2 in, IPS, 1080 x 1920 pixels, 24 bit', '2850 mAh, Li-Polymer', 'Android 7.0 Nougat', '4032 x 3024 pixels, 1920 x 1080 pixels, 30 fps', 'Nano-SIM', 'a, b, g, n, n 5GHz, ac, Dual band, Wi-Fi Hotspot, Wi-Fi Direct, Wi-Fi Display', '2.0, USB Type-C', '4.2', 'GPS, A-GPS, GLONASS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['71.8 x 141.5 x 9.95 mm', '156 g', 'Qualcomm Snapdragon 210 MSM8909', 'ARM Cortex-A7, 1100 MHz, Cores: 4', 'Qualcomm Adreno 304, 400 MHz', '1 GB, 533 MHz', '8 GB', 'microSD, microSDHC, microSDXC', '5 in, IPS, 480 x 854 pixels, 24 bit', '2050 mAh, Li-Polymer', 'Android 7.0 Nougat', '2592 x 1944 pixels, 1280 x 720 pixels, 30 fps', 'Nano-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.1', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['73 x 148 x 7.5 mm', '155 g', 'MediaTek MT6753', 'ARM Cortex-A53, 1300 MHz, Cores: 8', 'ARM Mali-T720 MP3, 450 MHz, Cores: 3', '3 GB, 666 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '5.2 in, IPS, 1080 x 1920 pixels, 24 bit', '2800 mAh, Li-Polymer', 'Android 7.1 Nougat', '4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps', 'Nano-SIM, Nano-SIM / microSD', 'a, b, g, n, Wi-Fi Hotspot, Wi-Fi Direct, Wi-Fi Display', '2.0, Micro USB', '4.2', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['81.5 x 159.6 x 8.65 mm', '175 g', 'MediaTek MT6750S', '4x 1.5 GHz ARM Cortex-A53, 4x 1.0 GHz ARM Cortex-A53, Cores: 8', 'ARM Mali-T860 MP2, Cores: 2', '3 GB, 667 MHz', '32 GB', 'microSD, microSDHC, microSDXC', '6 in, IPS, 1080 x 1920 pixels, 24 bit', '4000 mAh, Li-Polymer', 'Android 7.1 Nougat', '4032 x 3024 pixels, 1920 x 1080 pixels, 30 fps', 'Nano-SIM', 'a, b, g, n, n 5GHz, Dual band, Wi-Fi Hotspot, Wi-Fi Direct, Wi-Fi Display', '2.0, Micro USB', '4.2', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['76.96 x 151.9 x 8.4 mm', '157 g', 'MediaTek MT6738', 'ARM Cortex-A53, 1500 MHz, Cores: 4', 'ARM Mali-T860 MP2, 350 MHz, Cores: 2', '2 GB, 667 MHz', '32 GB', 'microSD, microSDHC, microSDXC', '5.5 in, IPS, 720 x 1280 pixels, 24 bit', '3000 mAh, Li-Polymer', 'Android 7.0 Nougat', '4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps', 'Nano-SIM', 'a, b, g, n, n 5GHz, Dual band, Wi-Fi Hotspot', '2.0, Micro USB', '4.2', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['71.4 x 141.8 x 8.95 mm', '129 g', 'MediaTek MT6737', 'ARM Cortex-A53, 1250 MHz, Cores: 4', 'ARM Mali-T720 MP1, 600 MHz, Cores: 1', '1 GB, 2 GB, 640 MHz', '8 GB, 16 GB', 'microSD, microSDHC, microSDXC', '5 in, IPS, 720 x 1280 pixels, 24 bit', '2200 mAh, Li-Polymer', 'Android 6.0 Marshmallow', '3264 x 2448 pixels, 1280 x 720 pixels, 30 fps', 'Nano-SIM', 'b, g, n, Wi-Fi Hotspot, Wi-Fi Direct', '2.0, Micro USB', '4.2', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['71.9 x 146.05 x 7.87 mm', '145 g', 'MediaTek MT6738', 'ARM Cortex-A53, 1500 MHz, Cores: 4', 'ARM Mali-T860 MP2, 350 MHz, Cores: 2', '2 GB, 667 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '5.2 in, IPS, 720 x 1280 pixels, 24 bit', '2800 mAh, Li-Polymer', 'Android 7.0 Nougat', '4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps', 'Nano-SIM', 'a, b, g, n, n 5GHz, Dual band, Wi-Fi Hotspot', '2.0, USB Type-C', '4.2', 'GPS, A-GPS, GLONASS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['70.87 x 148.6 x 7.4 mm', '148 g', 'Qualcomm Snapdragon 625 MSM8953', 'ARM Cortex-A53, 2000 MHz, Cores: 8', 'Qualcomm Adreno 506', '3 GB, 933 MHz', '32 GB', 'microSD, microSDHC, microSDXC', '5.2 in, IPS, 1080 x 1920 pixels, 24 bit', '2620 mAh, Li-Polymer', 'Android 7.1 Nougat', '4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps', 'Nano-SIM', 'a, b, g, n, n 5GHz, ac, Dual band, Wi-Fi Hotspot', '2.0, USB Type-C', '4.2', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['71.9 x 146.05 x 7.87 mm', '145 g', 'MediaTek MT6738', 'ARM Cortex-A53, 1500 MHz, Cores: 4', 'ARM Mali-T860 MP2, 350 MHz, Cores: 2', '2 GB, 667 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '5.2 in, IPS, 720 x 1280 pixels, 24 bit', '2800 mAh, Li-Polymer', 'Android 7.0 Nougat', '4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps', 'Nano-SIM', 'a, b, g, n, n 5GHz, Dual band, Wi-Fi Hotspot', '2.0, USB Type-C', '4.2', 'GPS, A-GPS, GLONASS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['71.8 x 141.5 x 9.99 mm', '153 g', 'Qualcomm Snapdragon 210 MSM8909', 'ARM Cortex-A7, 1100 MHz, Cores: 4', 'Qualcomm Adreno 304, 400 MHz', '1 GB, 533 MHz', '8 GB', 'microSD, microSDHC, microSDXC', '5 in, IPS, 480 x 854 pixels, 24 bit', '2050 mAh, Li-Polymer', 'Android 7.0 Nougat', '2592 x 1944 pixels, 1280 x 720 pixels, 30 fps', 'Nano-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.1', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['70.1 x 142 x 8.4 mm', '145 g', 'Qualcomm Snapdragon 210 MSM8909', 'ARM Cortex-A7, 1100 MHz, Cores: 4', 'Qualcomm Adreno 304, 400 MHz', '2 GB, 533 MHz', '16 GB', 'microSD, microSDHC', '5 in, IPS, 720 x 1280 pixels, 24 bit', '2460 mAh, Li-Polymer', 'Android 7.0 Nougat', '3264 x 2448 pixels, 1280 x 720 pixels, 30 fps', 'Nano-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.1', 'GPS, A-GPS']
#
#
# ['Dimensions', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['71.8 x 140.7 x 9.95 mm', 'MediaTek MT6737M', 'ARM Cortex-A53, 1100 MHz, Cores: 4', 'ARM Mali-T720 MP1, 550 MHz, Cores: 1', '1 GB, 640 MHz', '8 GB', 'microSD, microSDHC, microSDXC', '5 in, IPS, 480 x 854 pixels, 24 bit', '2050 mAh, Li-Polymer', 'Android 6.0 Marshmallow', '2592 x 1944 pixels, 1280 x 720 pixels, 30 fps', 'Micro-SIM', 'b, g, n, Wi-Fi Hotspot, Wi-Fi Direct', '2.0, Micro USB', '4.2', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['77.7 x 151.8 x 9.4 mm', '181 g', 'Qualcomm Snapdragon 210 MSM8909', 'ARM Cortex-A7, 1100 MHz, Cores: 4', 'Qualcomm Adreno 304, 400 MHz', '1 GB, 533 MHz', '8 GB', 'microSD, microSDHC', '5.5 in, IPS, 720 x 1280 pixels, 24 bit', '2500 mAh, Li-Polymer', 'Android 5.1 Lollipop', '2592 x 1944 pixels, 1280 x 720 pixels, 30 fps', 'Micro-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['83.8 x 165.1 x 8.4 mm', '186 g', 'Qualcomm Snapdragon 210 MSM8909', 'ARM Cortex-A7, 1100 MHz, Cores: 4', 'Qualcomm Adreno 304, 400 MHz', '2 GB, 533 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '6 in, IPS, 720 x 1280 pixels, 24 bit', '2580 mAh, Li-Ion', 'Android 6.0.1 Marshmallow', '3264 x 2446 pixels, 1280 x 720 pixels, 30 fps', 'Micro-SIM', 'a, b, g, n, n 5GHz, Dual band, Wi-Fi Hotspot', '2.0, Micro USB', '4.1', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['71.2 x 141.5 x 7.45 mm', '156 g', 'MediaTek MT6737', 'ARM Cortex-A53, 1300 MHz, Cores: 4', 'ARM Mali-T720 MP1, 600 MHz, Cores: 1', '2 GB, 640 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '5 in, IPS, 720 x 1280 pixels, 24 bit', '2460 mAh, Li-Polymer', 'Android 6.0 Marshmallow', '4160 x 3120 pixels, 1280 x 720 pixels, 30 fps', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['77 x 150.9 x 8.1 mm', '163 g', 'Qualcomm Snapdragon 210 MSM8909', 'ARM Cortex-A7, 1100 MHz, Cores: 4', 'Qualcomm Adreno 304, 400 MHz', '2 GB, 533 MHz', '16 GB', 'microSD, microSDHC', '5.5 in, IPS, 720 x 1280 pixels, 24 bit', '2500 mAh, Li-Polymer', 'Android 6.0.1 Marshmallow', '3264 x 2448 pixels, 1280 x 720 pixels, 30 fps', 'Nano-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.1', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['71.5 x 141 x 9.9 mm', '167 g', 'Qualcomm Snapdragon 210 MSM8909', 'ARM Cortex-A7, 1100 MHz, Cores: 4', 'Qualcomm Adreno 304, 400 MHz', '1 GB, 533 MHz', '8 GB', 'microSD, microSDHC, microSDXC', '5 in, TFT, 480 x 854 pixels, 24 bit', '2000 mAh, Li-Ion', 'Android 5.1 Lollipop', '2592 x 1944 pixels, 1280 x 720 pixels, 30 fps', 'Micro-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.1', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['65.1 x 132.2 x 10.05 mm', '136 g', 'Qualcomm Snapdragon 210 MSM8909', 'ARM Cortex-A7, 1100 MHz, Cores: 4', 'Qualcomm Adreno 304, 400 MHz', '1 GB, 533 MHz', '8 GB', 'microSD, microSDHC, microSDXC', '4.5 in, TFT, 480 x 854 pixels, 24 bit', '1780 mAh, Li-Ion', 'Android 5.1 Lollipop', '2592 x 1944 pixels, 1280 x 720 pixels, 30 fps', 'Micro-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['77.84 x 151.9 x 9.45 mm', '174 g', 'Qualcomm Snapdragon 210 MSM8909', 'ARM Cortex-A7, 1100 MHz, Cores: 4', 'Qualcomm Adreno 304, 400 MHz', '1.5 GB', '16 GB', 'microSD, microSDHC, microSDXC', '5.5 in, IPS, 720 x 1280 pixels, 24 bit', '2500 mAh, Li-Ion', 'Android 5.1 Lollipop', '3264 x 2448 pixels, 1280 x 720 pixels, 30 fps', 'Micro-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['192 x 110 x 9.4 mm', '295 g', 'Qualcomm Snapdragon 210 MSM8909', 'ARM Cortex-A7, 1100 MHz, Cores: 4', 'Qualcomm Adreno 304, 400 MHz', '1 GB, 533 MHz', '8 GB', 'microSD, microSDHC', '7 in, TFT, 1024 x 600 pixels, 24 bit', '3240 mAh, Li-Polymer', 'Android 6.0.1 Marshmallow', '2592 x 1944 pixels, 1280 x 720 pixels, 30 fps', 'b, g, n', '2.0, Micro USB', '4.1', 'GPS']
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['69.2 x 145 x 6.99 mm', '140 g', 'Qualcomm Snapdragon 415 MSM8929', '4x 1.4 GHz ARM Cortex-A53, 4x 1.0 GHz ARM Cortex-A53, Cores: 8', 'Qualcomm Adreno 405', '2 GB, 667 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '5 in, Super AMOLED, 720 x 1280 pixels, 24 bit', '2150 mAh, Li-Ion', 'Android 5.1 Lollipop', '4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps', 'Micro-SIM, Nano-SIM', 'b, g, n, Wi-Fi Hotspot, Wi-Fi Direct', '2.0, Micro USB', '4.0', 'GPS, A-GPS, GLONASS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['71.4 x 140.7 x 7.99 mm', '134 g', 'Qualcomm Snapdragon 210 MSM8909', 'ARM Cortex-A7, 1100 MHz, Cores: 4', 'Qualcomm Adreno 304, 400 MHz', '1 GB, 533 MHz', '8 GB', 'microSD, microSDHC', '5 in, IPS, 720 x 1280 pixels, 24 bit', '2500 mAh, Li-Ion', 'Android 6.0 Marshmallow', '3264 x 2448 pixels, 1280 x 720 pixels, 30 fps', 'Micro-SIM', 'b, g, n, Wi-Fi Hotspot, Wi-Fi Direct', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['72.5 x 147 x 7.1 mm', '135 g', 'Qualcomm Snapdragon 617 MSM8952', '4x 1.5 GHz ARM Cortex-A53, 4x 1.2 GHz ARM Cortex-A53, Cores: 8', 'Qualcomm Adreno 405', '2 GB, 3 GB, 933 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '5.2 in, IPS, 1080 x 1920 pixels, 24 bit', '2610 mAh, Li-Ion', 'Android 6.0.1 Marshmallow', '4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps', 'Nano-SIM', 'a, b, g, n, n 5GHz, ac, Dual band, Wi-Fi Hotspot, Wi-Fi Direct, Wi-Fi Display', '2.0, Micro USB', '4.2', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['66 x 133.5 x 9.9 mm', '136 g', 'Qualcomm Snapdragon 210 MSM8909', 'ARM Cortex-A7, 1100 MHz, Cores: 4', 'Qualcomm Adreno 304, 400 MHz', '1 GB, 533 MHz', '8 GB', 'microSD, microSDHC', '4.5 in, TFT, 480 x 854 pixels, 24 bit', '2000 mAh, Li-Ion', 'Android 5.1 Lollipop', '2592 x 1944 pixels, 1280 x 720 pixels, 30 fps', 'Micro-SIM', 'b, g, n, Wi-Fi Hotspot, Wi-Fi Direct', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['65.28 x 133.6 x 9.9 mm', '145 g', 'MediaTek MT6732', 'ARM Cortex-A53, 1500 MHz, Cores: 4', 'ARM Mali-T760 MP2, 500 MHz, Cores: 2', '1 GB, 800 MHz', '4 GB', 'microSD, microSDHC', '4.5 in, TFT, 540 x 960 pixels, 24 bit', '2000 mAh, Li-Ion', 'Android 4.4.4 KitKat', '2560 x 1920 pixels, 1920 x 1080 pixels, 30 fps', 'Micro-SIM', 'b, g, n, Wi-Fi Hotspot, Wi-Fi Direct', '2.0, Micro USB', '4.1', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['75.14 x 152.7 x 7.4 mm', '140 g', 'Qualcomm Snapdragon 615 MSM8939', '4x 1.5 GHz ARM Cortex-A53, 4x 1.0 GHz ARM Cortex-A53, Cores: 8', 'Qualcomm Adreno 405, 550 MHz', '2 GB, 800 MHz', '16 GB, 32 GB', 'microSD, microSDHC, microSDXC', '5.5 in, IPS, 1080 x 1920 pixels, 24 bit', '2910 mAh, Li-Polymer', 'Android 5.0 Lollipop', '4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps', 'Micro-SIM', 'a, b, g, n, n 5GHz, Dual band, Wi-Fi Hotspot, Wi-Fi Direct, Wi-Fi Display', '2.0, Micro USB', '4.1', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['65.1 x 132.2 x 9.95 mm', '125 g', 'MediaTek MT6735M', 'ARM Cortex-A53, 1000 MHz, Cores: 4', 'ARM Mali-T720 MP1, 500 MHz, Cores: 1', '1 GB, 533 MHz', '8 GB', 'microSD, microSDHC', '4.5 in, TFT, 480 x 854 pixels, 24 bit', '1780 mAh, Li-Ion', 'Android 4.4.2 KitKat', '3264 x 2448 pixels, 1280 x 720 pixels, 30 fps', 'Micro-SIM', 'a, b, g, n, Wi-Fi Hotspot, Wi-Fi Direct, Wi-Fi Display', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['65.1 x 132.2 x 11.7 mm', '125 g', 'MediaTek MT6572M', 'ARM Cortex-A7, 1000 MHz, Cores: 2', 'ARM Mali-400 MP1, 400 MHz, Cores: 1', '512 MB, 1 GB', '4 GB', 'microSD, microSDHC', '4.5 in, TFT, 480 x 854 pixels, 24 bit', '1400 mAh, Li-Ion', 'Android 4.4.2 KitKat', '3264 x 2448 pixels, 1280 x 720 pixels, 30 fps', 'Micro-SIM', 'b, g, n, Wi-Fi Hotspot, Wi-Fi Direct, Wi-Fi Display', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['71.9 x 141 x 9.9 mm', '149 g', 'Qualcomm Snapdragon 200 MSM8212', 'ARM Cortex-A7, 1200 MHz, Cores: 4', 'Qualcomm Adreno 302', '1 GB', '4 GB', 'microSD, microSDHC', '5 in, TFT, 540 x 960 pixels, 18 bit', '2000 mAh, Li-Ion', 'Android 4.4 KitKat', '2592 x 1944 pixels, 1280 x 720 pixels, 30 fps', 'Micro-SIM', 'b, g, n, Wi-Fi Hotspot, Wi-Fi Direct', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['64.4 x 121.6 x 12.05 mm', '110 g', 'MediaTek MT6571', 'ARM Cortex-A7, 1300 MHz, Cores: 2', 'ARM Mali-400 MP1, Cores: 1', '512 MB', '4 GB', 'microSD, microSDHC', '4 in, TFT, 480 x 800 pixels, 18 bit', '1400 mAh, Li-Ion', 'Android 4.4.2 KitKat', '2592 x 1944 pixels, 640 x 480 pixels, 30 fps', 'Micro-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['64.4 x 121.5 x 12.35 mm', '125 g', 'Qualcomm Snapdragon 410 MSM8916', 'ARM Cortex-A53, 1200 MHz, Cores: 4', 'Qualcomm Adreno 306, 400 MHz', '1 GB, 533 MHz', '4 GB', 'microSD, microSDHC', '4 in, TFT, 480 x 800 pixels, 24 bit', '2000 mAh, Li-Ion', 'Android 5.0 Lollipop', '3264 x 2448 pixels, 1280 x 720 pixels, 30 fps', 'Micro-SIM', 'b, g, n, Wi-Fi Hotspot, Wi-Fi Direct, Wi-Fi Display', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'Wi-Fi', 'USB', 'Bluetooth']
# ['192 x 110 x 9.95 mm', '285 g', 'MediaTek MT8117', 'ARM Cortex-A7, 1200 MHz, Cores: 2', 'PowerVR SGX544', '512 MB, 1 GB', '4 GB, 8 GB', 'microSD, microSDHC, microSDXC', '7 in, TFT, 960 x 540 pixels, 24 bit', '2840 mAh, Li-Ion', 'Android 4.4.2 KitKat', '640 x 480 pixels, 640 x 480 pixels, 30 fps', 'b, g, n', '2.0, Micro USB', '4.0']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ...
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['71.5 x 143.9 x 8 mm', '169 g', 'MediaTek MT6735P', 'ARM Cortex-A53, 1000 MHz, Cores: 4', 'ARM Mali-T720 MP1, 400 MHz, Cores: 1', '3 GB, 533 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '5 in, IPS, 720 x 1280 pixels, 24 bit', '2450 mAh, Li-Ion', 'Android 5.1 Lollipop', '4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps', 'Micro-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['72 x 143 x 11.35 mm', '204 g', 'MediaTek MT6580', 'ARM Cortex-A7, 1300 MHz, Cores: 4', 'ARM Mali-400 MP2, Cores: 2', '2 GB, 533 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '5 in, IPS, 720 x 1280 pixels, 24 bit', '3000 mAh, Li-Ion', 'Android 6.0 Marshmallow', '4160 x 3120 pixels, 1280 x 720 pixels, 30 fps', 'Mini-SIM, Micro-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['83.5 x 164.5 x 8.95 mm', '203 g', 'MediaTek MT6753A', 'ARM Cortex-A53, 1000 MHz, Cores: 8', 'ARM Mali-T720 MP3, Cores: 3', '3 GB, 666 MHz', '32 GB', 'microSD, microSDHC, microSDXC', '6 in, IPS, 720 x 1280 pixels, 24 bit', '4100 mAh, Li-Polymer', 'Android 6.0 Marshmallow', '3264 x 2448 pixels, 1280 x 720 pixels, 30 fps', 'Micro-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['69.4 x 143.5 x 7 mm', '150 g', 'MediaTek MT6735A', 'ARM Cortex-A53, 1300 MHz, Cores: 4', 'ARM Mali-T720 MP1, 450 MHz, Cores: 1', '3 GB, 533 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '5 in, IPS, 720 x 1280 pixels, 24 bit', '2700 mAh, Li-Ion', 'Android 6.0 Marshmallow', '4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps', 'Micro-SIM, Nano-SIM / microSD', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.0', 'GPS, A-GPS, GLONASS']
#
#
# ['Dimensions', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['72 x 142 x 8.8 mm', 'MediaTek MT6580', 'ARM Cortex-A7, 1300 MHz, Cores: 4', 'ARM Mali-400 MP2, Cores: 2', '1 GB, 533 MHz', '16 GB', 'microSD, microSDHC', '5 in, IPS, 720 x 1280 pixels, 24 bit', '2200 mAh, Li-Ion', 'Android 6.0 Marshmallow', '3264 x 2448 pixels, 1280 x 720 pixels, 30 fps', 'Micro-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['77.2 x 152.3 x 8.8 mm', '202 g', 'MediaTek MT6735A', 'ARM Cortex-A53, 1300 MHz, Cores: 4', 'ARM Mali-T720 MP1, 450 MHz, Cores: 1', '3 GB, 533 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '5.5 in, IPS, 720 x 1280 pixels, 24 bit', '4150 mAh, Li-Ion', 'Android 6.0 Marshmallow', '3264 x 2448 pixels, 1920 x 1080 pixels, 30 fps', 'Micro-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.0', 'GPS, A-GPS, GLONASS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['76.5 x 149.9 x 9.1 mm', '230 g', 'MediaTek MT6735A', 'ARM Cortex-A53, 1300 MHz, Cores: 4', 'ARM Mali-T720 MP1, 450 MHz, Cores: 1', '3 GB, 533 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '5.5 in, IPS, 720 x 1280 pixels, 24 bit', '5000 mAh, Li-Polymer', 'Android 5.1.1 Lollipop', '3264 x 2448 pixels, 1920 x 1080 pixels, 30 fps', 'Micro-SIM, Micro-SIM / microSD', 'b, g, n, Wi-Fi Hotspot, Wi-Fi Direct', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['74.9 x 149 x 7.95 mm', 'MediaTek MT6753', 'ARM Cortex-A53, 1500 MHz, Cores: 8', 'ARM Mali-T720 MP3, 450 MHz, Cores: 3', '3 GB, 666 MHz', '32 GB', 'microSD, microSDHC, microSDXC', '5.5 in, IPS, 1080 x 1920 pixels, 24 bit', '3050 mAh, Li-Polymer', 'Android 5.1.1 Lollipop', '4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps', 'Micro-SIM, Nano-SIM / microSD', 'b, g, n, n 5GHz, Wi-Fi Hotspot', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['76.5 x 151.7 x 7 mm', 'MediaTek MT6735A', 'ARM Cortex-A53, 1300 MHz, Cores: 4', 'ARM Mali-T720 MP1, 450 MHz, Cores: 1', '3 GB, 533 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '5.5 in, IPS, 720 x 1280 pixels, 24 bit', '3000 mAh, Li-Polymer', 'Android 5.1 Lollipop', '3264 x 2448 pixels, 1920 x 1080 pixels, 30 fps', 'Micro-SIM, Nano-SIM / microSD', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['76.5 x 151.7 x 7 mm', 'MediaTek MT6735', 'ARM Cortex-A53, 1300 MHz, Cores: 4', 'ARM Mali-T720 MP1, 600 MHz, Cores: 1', '2 GB, 640 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '5.5 in, IPS, 720 x 1280 pixels, 24 bit', '3000 mAh, Li-Polymer', 'Android 5.1 Lollipop', '3264 x 2448 pixels, 1920 x 1080 pixels, 30 fps', 'Micro-SIM, Nano-SIM / microSD', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['77.2 x 152.3 x 8.8 mm', '163 g', 'MediaTek MT6580', 'ARM Cortex-A7, 1300 MHz, Cores: 4', 'ARM Mali-400 MP2, Cores: 2', '2 GB, 533 MHz', '16 GB', 'microSD, microSDHC', '5.5 in, IPS, 720 x 1280 pixels, 24 bit', '4150 mAh, Li-Ion', 'Android 5.1 Lollipop', '2592 x 1944 pixels, 1920 x 1080 pixels, 30 fps', 'Micro-SIM', 'b, g, n, Wi-Fi Hotspot, Wi-Fi Display', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['69.4 x 143.4 x 6.2 mm', '145 g', 'MediaTek MT6735A', 'ARM Cortex-A53, 1300 MHz, Cores: 4', 'ARM Mali-T720 MP1, 450 MHz, Cores: 1', '2 GB, 533 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '5 in, JDI IPS, 1080 x 1920 pixels, 24 bit', '2500 mAh, Li-Ion', 'Android 5.1 Lollipop', '4608 x 3456 pixels, 1920 x 1080 pixels, 30 fps', 'Micro-SIM / microSD, Nano-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.0', 'GPS, A-GPS, GLONASS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['76 x 153 x 6.9 mm', '181 g', 'MediaTek MT6735A', 'ARM Cortex-A53, 1300 MHz, Cores: 4', 'ARM Mali-T720 MP1, 450 MHz, Cores: 1', '2 GB, 533 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '5.5 in, IPS, 1080 x 1920 pixels, 24 bit', '2750 mAh, Li-Ion', 'Android 5.1 Lollipop', '4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps', 'Micro-SIM, Nano-SIM / microSD', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['71.2 x 143.8 x 8.1 mm', '143 g', 'MediaTek MT6735M', 'ARM Cortex-A53, 1000 MHz, Cores: 4', 'ARM Mali-T720 MP1, 500 MHz, Cores: 1', '1 GB, 533 MHz', '8 GB', 'microSD, microSDHC', '5 in, IPS, 540 x 960 pixels, 24 bit', '2200 mAh, Li-Ion', 'Android 5.1 Lollipop', '3264 x 2448 pixels, 1920 x 1080 pixels, 30 fps', 'Micro-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['75 x 151.3 x 6.5 mm', '150 g', 'MediaTek MT6592M', 'ARM Cortex-A7, 1400 MHz, Cores: 8', 'ARM Mali-450 MP4, 600 MHz, Cores: 4', '2 GB', '16 GB', '5.5 in, JDI IPS, 720 x 1280 pixels, 24 bit', '2850 mAh, Li-Polymer', 'Android 4.4.2 KitKat', '4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps', 'Micro-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['76.5 x 153.8 x 7.3 mm', '160 g', 'MediaTek MT6592M', 'ARM Cortex-A7, 1400 MHz, Cores: 8', 'ARM Mali-450 MP4, 600 MHz, Cores: 4', '2 GB', '16 GB', 'microSD, microSDHC, microSDXC', '5.5 in, IPS, 720 x 1280 pixels, 24 bit', '2400 mAh, Li-Ion', 'Android 4.4 KitKat', '4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps', 'Micro-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['71 x 140 x 7.9 mm', '150 g', 'Qualcomm Snapdragon 410 MSM8916', 'ARM Cortex-A53, 1200 MHz, Cores: 4', 'Qualcomm Adreno 306, 400 MHz', '1 GB, 533 MHz', '8 GB', 'microSD, microSDHC', '5 in, IPS, 720 x 1280 pixels, 24 bit', '2200 mAh, Li-Ion', 'Android 4.4.4 KitKat', '4128 x 3096 pixels, 1280 x 720 pixels, 30 fps', 'Micro-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth']
# ['65 x 129 x 10 mm', '115 g', 'MediaTek MT6572', 'ARM Cortex-A7, 1300 MHz, Cores: 2', 'ARM Mali-400 MP1, 500 MHz, Cores: 1', '512 MB, 266 MHz', '4 GB', 'microSD, microSDHC, microSDXC', '4 in, LCD, 480 x 800 pixels, 24 bit', '1350 mAh, Li-Ion', 'Android 4.2.2 Jelly Bean', '2592 x 1944 pixels', 'Mini-SIM, Micro-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '2.0']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['73 x 142 x 8.2 mm', '154 g', 'MediaTek MT6582', 'ARM Cortex-A7, 1300 MHz, Cores: 4', 'ARM Mali-400 MP2, 500 MHz, Cores: 2', '2 GB, 533 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '5 in, IPS, 720 x 1280 pixels, 24 bit', '2000 mAh, Li-Ion', 'Android 4.2.2 Jelly Bean', '3264 x 2448 pixels, 1920 x 1080 pixels, 30 fps', 'Mini-SIM, Micro-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '2.0', 'GPS, A-GPS, EPO']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['71.6 x 145.2 x 8.1 mm', '178 g', 'MediaTek MT6582', 'ARM Cortex-A7, 1300 MHz, Cores: 4', 'ARM Mali-400 MP2, 500 MHz, Cores: 2', '1 GB, 533 MHz', '16 GB', 'microSD, microSDHC, microSDXC', '5 in, IPS, 540 x 960 pixels, 24 bit', '2000 mAh, Li-Ion', 'Android 4.2.2 Jelly Bean', '3264 x 2448 pixels, 1920 x 1080 pixels, 30 fps', 'Mini-SIM, Micro-SIM', 'b, g, n, Wi-Fi Hotspot', '2.0, Micro USB', '2.1', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['74 x 140 x 9 mm', '176 g', 'MediaTek MT6572W', 'ARM Cortex-A7, 1200 MHz, Cores: 2', 'ARM Mali-400 MP1, 400 MHz, Cores: 1', '512 MB, 266 MHz', '4 GB', 'microSD, microSDHC', '5 in, IPS, 540 x 960 pixels, 18 bit', '2200 mAh, Li-Ion', 'Android 4.2 Jelly Bean', '3264 x 2448 pixels', 'b, g, n', '2.0, Micro USB', '3.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['72.9 x 145.5 x 11 mm', '186 g', 'MediaTek MT6572W', 'ARM Cortex-A7, 1300 MHz, Cores: 2', 'ARM Mali-400 MP1, 500 MHz, Cores: 1', '512 MB, 266 MHz', '4 GB', 'microSD, microSDHC', '5 in, IPS, 540 x 960 pixels, 18 bit', '3400 mAh, Li-Ion', 'Android 4.2.2 Jelly Bean', '3264 x 2448 pixels', 'b, g, n', '2.0, Micro USB', '2.1', 'GPS, A-GPS, EPO']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['262.6 x 175.8 x 9.9 mm', '656 g', 'Intel Atom Z3735F', 'Intel Bay Trail, 1330 MHz, Cores: 4', 'Intel HD Graphics, 646 MHz', '2 GB, 1333 MHz', '32 GB', 'microSD, microSDHC, microSDXC', '10.1 in, IPS, 1920 x 1200 pixels, 24 bit', '6500 mAh, Li-Polymer', 'Microsoft Windows 8.1', '2592 x 1944 pixels, 1920 x 1080 pixels, 30 fps', 'Micro-SIM', 'a, b, g, n, Wi-Fi Display', '2.0, Micro USB', '4.0', 'GPS, A-GPS, GLONASS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'Wi-Fi', 'USB', 'Bluetooth']
# ['262.6 x 175.8 x 9.9 mm', '656 g', 'Intel Atom Z3735F', 'Intel Bay Trail, 1330 MHz, Cores: 4', 'Intel HD Graphics, 646 MHz', '2 GB, 1333 MHz', '64 GB', 'microSD, microSDHC, microSDXC', '10.1 in, IPS, 1920 x 1200 pixels, 24 bit', '6500 mAh, Li-Polymer', 'Microsoft Windows 8.1', '2592 x 1944 pixels, 1920 x 1080 pixels, 30 fps', 'a, b, g, n, Wi-Fi Display', '2.0, Micro USB', '4.0']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['262.6 x 175.8 x 9.9 mm', '656 g', 'Intel Atom Z3735F', 'Intel Bay Trail, 1330 MHz, Cores: 4', 'Intel HD Graphics, 646 MHz', '2 GB, 1333 MHz', '32 GB', 'microSD, microSDHC, microSDXC', '10.1 in, IPS, 1280 x 800 pixels, 24 bit', '6500 mAh, Li-Polymer', 'Microsoft Windows 8.1', '2592 x 1944 pixels, 1920 x 1080 pixels, 30 fps', 'Micro-SIM', 'a, b, g, n, Wi-Fi Display', '2.0, Micro USB', '4.0', 'GPS, A-GPS, GLONASS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'Wi-Fi', 'USB', 'Bluetooth']
# ['262.6 x 175.8 x 9.9 mm', '656 g', 'Intel Atom Z3735F', 'Intel Bay Trail, 1330 MHz, Cores: 4', 'Intel HD Graphics, 646 MHz', '2 GB, 1333 MHz', '32 GB, 64 GB', 'microSD, microSDHC, microSDXC', '10.1 in, IPS, 1280 x 800 pixels, 24 bit', '6500 mAh, Li-Polymer', 'Microsoft Windows 8.1', '2592 x 1944 pixels, 1920 x 1080 pixels, 30 fps', 'a, b, g, n, Wi-Fi Display', '2.0, Micro USB', '4.0']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'Wi-Fi', 'USB', 'Bluetooth', 'Positioning']
# ['215.9 x 124.2 x 6 mm', '305 g', 'Intel Atom Z3580', 'Intel Silvermont, 2300 MHz, Cores: 4', 'PowerVR G6430 MP4, 533 MHz, Cores: 4', '2 GB', '16 GB, 32 GB', 'microSD, microSDHC', '8.4 in, OLED, 2560 x 1600 pixels, 24 bit', '5670 mAh, Li-Polymer', 'Android 4.4.2 KitKat', '3264 x 2448 pixels, 1920 x 1080 pixels, 30 fps', 'b, g, n, ac, Wi-Fi Display', '2.0, Micro USB', '4.0', 'GPS, A-GPS']
#
#
# ['Dimensions', 'Weight', 'SoC', 'CPU', 'GPU', 'RAM', 'Storage', 'Memory cards', 'Display', 'Battery', 'OS', 'Camera', 'SIM card', 'Wi-Fi', 'USB', 'Bluetooth']
# ['216 x 130 x 8.95 mm', '338 g', 'Intel Atom Z3480', 'Intel Silvermont, 2100 MHz, Cores: 2', 'PowerVR G6400 MP4, 533 MHz, Cores: 4', '1 GB', '16 GB', 'microSD, microSDHC, microSDXC', '8 in, IPS, 1920 x 1200 pixels, 24 bit', '4550 mAh, Li-Ion', 'Android 4.4.2 KitKat', '2592 x 1944 pixels, 1920 x 1080 pixels, 30 fps', 'Micro-SIM', 'a, b, g, n, ac, Wi-Fi Hotspot', '2.0, Micro USB', '4.0']

# %%
wf = open('information_next_2.txt', 'w')
for i in range(len(labels_of_each_product)):
    for lab in labels_of_each_product[i]:
        wf.write(lab + '\t')
    wf.write('\n')
    for det in details_of_each_product[i]:
        wf.write(det + '\t')
    wf.write('\n\n')
wf.close()

# %%
len(labels_of_each_product)
# Out:
# 500
