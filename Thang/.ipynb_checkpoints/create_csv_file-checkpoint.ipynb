# %%
import pandas as pd
from decimal import *

# %%
label = set()
rf = open('information.txt', 'r')
i = 1
line = rf.readline()
while(line != ''):
    if((i%3) == 1):
        labs = line.strip().split('\t')
        for lab in labs:
            label.add(lab)
    
    i = i+1
    line = rf.readline()
rf.close()

# %%
label
# Out:
# {'Battery',
#  'Bluetooth',
#  'CPU',
#  'Camera',
#  'Cores',
#  'Dimensions',
#  'Display',
#  'GPU',
#  'Memory cards',
#  'OS',
#  'Positioning',
#  'RAM',
#  'SIM card',
#  'SoC',
#  'Storage',
#  'USB',
#  'Weight',
#  'Wi-Fi'}

# %%
Battery = []
Bluetooth = []
CPU = []
Camera = []
Cores = []
Dimensions = []
Display = []
GPU = []
Memory_cards = []
OS = []
Positioning = []
RAM = []
SIM_card = []
SoC = []
Storage = []
USB = []
Weight = []
Wi_Fi = []

rf = open('information.txt', 'r')
for m in range(i):
    line = rf.readline()
    if((m%3) == 0):
        labs = line.strip().split('\t')
    if((m%3) == 1):
        detail = line.strip().split('\t')
    if((m%3) == 2):
        if('Battery' in labs):
            index = labs.index('Battery')
            Battery.append(detail[index])
        else:
            Battery.append('No info')
    
        if('Bluetooth' in labs):
            index = labs.index('Bluetooth')
            Bluetooth.append(detail[index])
        else:
            Bluetooth.append('No info')
        
        if('CPU' in labs):
            index = labs.index('CPU')
            CPU.append(detail[index])
        else:
            CPU.append('No info')
        
        if('Camera' in labs):
            index = labs.index('Camera')
            Camera.append(detail[index])
        else:
            Camera.append('No info')
        
        if('Cores' in labs):
            index = labs.index('Cores')
            Cores.append(detail[index])
        else:
            Cores.append('No info')
        
        if('Dimensions' in labs):
            index = labs.index('Dimensions')
            Dimensions.append(detail[index])
        else:
            Dimensions.append('No info')
    
        if('Display' in labs):
            index = labs.index('Display')
            Display.append(detail[index])
        else:
            Display.append('No info')
    
        if('GPU' in labs):
            index = labs.index('GPU')
            GPU.append(detail[index])
        else:
            GPU.append('No info')
    
        if('Memory cards' in labs):
            index = labs.index('Memory cards')
            Memory_cards.append(detail[index])
        else:
            Memory_cards.append('No info')
    
        if('OS' in labs):
            index = labs.index('OS')
            OS.append(detail[index])
        else:
            OS.append('No info')
    
        if('Positioning' in labs):
            index = labs.index('Positioning')
            Positioning.append(detail[index])
        else:
            Positioning.append('No info')
    
        if('RAM' in labs):
            index = labs.index('RAM')
            RAM.append(detail[index])
        else:
            RAM.append('No info')
    
        if('SIM card' in labs):
            index = labs.index('SIM card')
            SIM_card.append(detail[index])
        else:
            SIM_card.append('No info')
        
        if('SoC' in labs):
            index = labs.index('SoC')
            SoC.append(detail[index])
        else:
            SoC.append('No info')
        
        if('Storage' in labs):
            index = labs.index('Storage')
            Storage.append(detail[index])
        else:
            Storage.append('No info')
        
        if('USB' in labs):
            index = labs.index('USB')
            USB.append(detail[index])
        else:
            USB.append('No info')
        
        if('Weight' in labs):
            index = labs.index('Weight')
            Weight.append(detail[index])
        else:
            Weight.append('No info')
        
        if('Wi-Fi' in labs):
            index = labs.index('Wi-Fi')
            Wi_Fi.append(detail[index])
        else:
            Wi_Fi.append('No info')

# %%
brand = []
name = []
avg_price = []
fo = open('name_and_price.txt', 'r')
for m in range(i):
    line = fo.readline()
    if((m%3) == 1):
        average = 0
        info = line.strip().split('\t')
        if (info[0] == 'No info'):
            brand.append('No info')
            name.append('No info')
            avg_price.append('No info')
        else:
            brand_name = info[0].split(' ')
            brand.append(brand_name[-2])
            name.append(brand_name[-1])
        
            prices = info[1].replace('$', '')
            prices = prices.split(', ')
            print(m)
            print(prices)
            for price in prices:
                average += Decimal(price)
            average = average/len(prices)
            avg_price.append(round(average, 2))
# Out:
# 1
# ['229.90', '239.00', '319.00']
# 4
# ['185.00']
# 7
# ['229.90', '239.00', '319.00']
# 10
# ['197.11']
# 13
# ['463.27']
# 16
# ['317.18']
# 19
# ['231.13']
# 22
# ['168.22']
# 25
# ['299.00', '301.80', '308.93', '314.98', '319.58', '497.80']
# 28
# ['79.00', '89.00', '89.99', '99.99', '104.99']
# 31
# ['249.00']
# 34
# ['194.41', '198.19', '198.79', '198.79', '198.79', '199.99', '200.90', '202.13', '205.56', '229.99', '236.95', '251.89', '259.99', '289.00', '289.00', '289.99', '289.99', '289.99', '301.95', '303.05', '319.99', '321.43', '321.55', '369.00', '369.99', '369.99', '457.56']
# 37
# ['473.84', '473.99', '499.99', '499.99', '499.99', '499.99', '499.99', '513.42', '521.99', '535.99', '551.54', '564.95', '579.99', '598.80', '601.95', '627.20', '629.99', '644.95', '649.99', '657.81', '659.88', '669.95', '699.99', '711.95', '739.99', '800.16', '800.16', '801.94', '848.27', '895.18', '895.18', '912.22', '965.56', '1099.63']
# 40
# ['284.99', '299.99', '300.29', '313.99', '319.99', '319.99', '329.99', '335.16', '384.95', '407.12', '429.99', '429.99', '429.99', '438.00', '482.02', '535.00', '567.53', '657.00']
# 43
# ['124.48']
# 46
# ['113.05', '177.00']
# 49
# ['99.59', '125.99', '126.62', '152.99']
# 52
# ['91.00']
# 55
# ['165.99']
# 58
# ['311.22', '315.99', '365.99', '451.95', '463.39', '498.37', '522.77', '527.52', '569.57', '591.95', '599.00', '657.00', '669.99', '743.57', '843.88']
# 61
# ['133.49', '139.16', '139.99', '142.80', '147.06', '149.59', '149.99', '159.90', '159.99', '162.54', '173.95', '179.99', '179.99', '179.99', '193.95', '199.99', '199.99', '269.22']
# 64
# ['106.93', '131.95', '179.99']
# 67
# ['165.88', '166.77', '268.87', '271.68', '290.95']
# 70
# ['169.99']
# 73
# ['198.00']
# 76
# ['69.90']
# 79
# ['109.99', '120.00', '124.48']
# 82
# ['57.99', '60.98', '63.99', '63.99', '64.95', '64.99', '64.99', '69.98', '79.95']
# 85
# ['74.00', '79.00', '89.99', '99.99']
# 88
# ['149.00']
# 91
# ['59.99', '69.59', '69.97', '74.98', '74.98', '74.99', '89.99']
# 94
# ['52.00', '52.00', '52.99', '52.99', '55.53', '56.95', '59.99', '89.99', '264.95']
# 97
# ['89.99', '98.99', '99.99', '99.99', '108.00', '120.00', '149.00', '189.00']
# 100
# ['234.90', '256.90']
# 103
# ['149.99']
# 106
# ['64.99']
# 109
# ['61.97', '136.90']
# 112
# ['59.97', '74.00', '75.00', '79.00', '89.99', '101.12', '116.10', '116.10', '134.16']
# 115
# ['169.99']
# 118
# ['84.14', '89.99']
# 121
# ['118.99', '174.91', '174.91', '189.90', '197.80']
# 124
# ['50.43', '55.00', '55.98', '57.99', '58.99', '59.49', '59.95', '59.98', '59.99', '120.00']
# 127
# ['89.00']
# 130
# ['53.00', '54.00', '57.00', '57.99', '58.90', '59.99', '60.99', '62.99', '65.00', '69.99']
# 133
# ['69.99']
# 136
# ['54.00', '54.00']
# 139
# ['69.99']
# 142
# ['190.46']
# 145
# ['99.00']
# 148
# ['145.00', '200.00']
# 151
# ['50.00', '51.10', '52.00', '52.99', '54.99', '59.99', '59.99', '67.00', '71.99', '74.90']
# 154
# ['93.39', '94.99', '95.00', '95.99', '99.99', '109.90', '139.99', '145.00', '149.00', '239.00']
# 157
# ['74.50', '74.50', '74.50', '80.00', '80.00']
# 160
# ['52.48', '52.49', '54.00', '54.99', '54.99', '57.99', '58.90', '59.99', '60.99', '64.99']
# 163
# ['59.90', '69.90', '70.00']
# 166
# ['73.95', '79.00', '87.36', '87.99', '97.99', '129.00', '199.00']
# 169
# ['55.99']
# 172
# ['69.99', '69.99', '79.19']
# 175
# ['114.95', '149.99']
# 178
# ['54.99', '58.99', '59.99', '64.99', '68.99', '69.00', '74.00']
# 181
# ['54.99']
# 184
# ['52.49', '53.99', '54.99', '54.99', '54.99', '71.61', '74.99', '88.55', '99.99']
# 187
# ['54.99', '59.98', '69.99', '81.49']
# 190
# ['59.99', '80.00']
# 193
# ['72.00', '123.00', '159.50', '159.95']
# 196
# ['69.99']
# 199
# ['59.88', '120.00']
# 202
# ['75.00', '125.00']
# 205
# ['125.00']
# 208
# ['80.08', '95.00']
# 211
# ['96.00']
# 214
# ['63.99']
# 217
# ['64.88']
# 220
# ['129.00']
# 223
# ['79.99']
# 226
# ['79.50']
# 229
# ['136.36', '138.00']
# 232
# ['65.00']
# 235
# ['69.50', '84.50']
# 238
# ['64.90']
# 241
# ['52.36']
# 244
# ['259.00']
# 247
# ['96.44', '98.99', '99.99', '99.99', '165.02']
# 250
# ['59.63', '63.99', '63.99', '63.99', '65.14', '74.39', '109.99', '110.99']
# 253
# ['47.09', '59.99', '63.34', '63.34', '68.61', '69.99', '69.99', '99.43']
# 256
# ['55.68', '58.99', '58.99', '58.99', '59.19', '59.19', '59.19', '62.99', '67.99', '69.99', '70.99', '72.99', '72.99', '72.99', '75.87', '75.99', '76.67', '76.67', '79.99', '80.95', '82.69', '86.70', '94.29', '101.77', '175.00']
# 259
# ['84.99', '86.66', '155.22', '168.67', '194.11', '197.79', '203.84', '209.99', '216.30', '216.95', '216.95', '262.22', '287.32', '299.99']
# 262
# ['48.47', '56.93', '56.93', '59.24', '69.78', '69.99', '149.99', '149.99']
# 265
# ['65.19', '76.99', '79.99', '79.99', '83.85', '83.85', '89.99', '116.17']
# 268
# ['51.78', '68.16', '68.16', '99.99']
# 271
# ['75.93']
# 274
# ['52.08', '62.99', '67.69', '67.69', '69.99', '69.99', '74.70', '75.99', '77.00', '77.55', '78.99', '78.99', '79.99', '95.92', '106.38', '106.38', '210.99']
# 277
# ['60.83', '67.69', '75.99', '76.48', '78.17', '78.17', '82.99', '110.92']
# 280
# ['87.90', '89.00', '93.61', '93.96', '93.96', '105.55', '106.99', '108.99', '109.99', '109.99', '109.99', '109.99', '110.00', '110.10', '111.99', '113.99', '115.99', '119.99', '132.45', '182.02', '274.99']
# 283
# ['64.19', '68.77', '68.98', '69.99', '75.99', '79.90', '79.99', '79.99', '80.00', '80.18', '81.83', '85.99', '86.47', '87.50', '93.99', '96.15', '99.99', '119.37', '218.99']
# 286
# ['150.90', '161.99', '169.99', '172.28', '173.28', '175.26', '179.99', '179.99', '179.99', '182.99', '189.99', '192.00', '192.02', '225.07']
# 289
# ['96.72', '121.46', '126.99', '133.46', '136.39', '138.66', '139.99', '139.99', '140.60', '141.13', '144.95', '153.99', '157.70', '165.09', '179.99', '189.65', '189.65', '376.27']
# 292
# ['96.72', '106.09', '113.15', '119.90', '124.99', '127.98', '129.99', '129.99', '129.99', '129.99', '129.99', '130.49', '131.18', '137.00', '139.99', '149.99', '179.99', '326.99']
# 295
# ['121.56', '149.00', '149.99', '155.99', '158.50']
# 298
# ['142.45', '163.99', '164.99', '169.99', '239.99', '254.27']
# 301
# ['229.99', '237.00', '249.00', '249.00', '249.99', '259.99', '269.99']
# 304
# ['134.61', '139.99', '156.99', '158.99', '159.99', '159.99', '159.99', '162.99', '179.99', '214.99', '217.29', '267.50']
# 307
# ['217.44', '229.99', '230.41', '233.57', '234.47', '235.99', '242.12', '249.99', '249.99', '253.99', '267.82', '279.99', '280.00', '285.99', '286.70', '313.86', '336.99', '359.00', '373.99', '385.00', '385.00', '410.58', '433.32']
# 310
# ['117.84', '149.99', '149.99', '149.99', '149.99', '149.99', '149.99', '155.00', '159.03', '185.25']
# 313
# ['110.05', '193.55']
# 316
# ['100.84', '116.98', '118.91', '124.99', '125.65', '136.99', '172.49', '179.37']
# 319
# ['55.91', '185.00']
# 322
# ['97.52']
# 325
# ['125.99', '137.34', '245.99']
# 328
# ['137.34', '147.99', '148.99']
# 331
# ['342.19', '369.99', '404.99']
# 334
# ['150.93']
# 337
# ['82.05', '82.74', '91.25', '96.79']
# 340
# ['69.99', '139.99']
# 343
# ['59.75', '59.99', '62.99', '63.99']
# 346
# ['119.99', '124.99', '124.99', '129.99', '139.99', '144.54', '210.69']
# 349
# ['62.99', '74.99', '74.99', '74.99']
# 352
# ['62.99']
# 355
# ['124.98', '124.99', '149.99']
# 358
# ['295.00']
# 361
# ['79.99', '99.88', '169.95']
# 364
# ['61.64']
# 367
# ['988.88', '1080.00', '1220.00', '1445.00', '1563.17', '1623.93', '1815.64']
# 370
# ['898.88', '1075.00', '1089.99', '1130.00', '1149.49', '1199.00', '1249.99', '1379.99', '1469.93', '1490.00', '2099.00']
# 373
# ['685.00', '740.00', '840.99', '890.88', '899.00']
# 376
# ['379.99', '449.99', '465.00', '499.85', '549.00', '699.99']
# 379
# ['379.99', '449.99', '465.00', '549.00', '599.85']
# 382
# ['125.64', '130.19', '143.43', '151.22', '152.10', '152.10', '155.88', '156.75', '158.00', '169.98', '209.90', '225.99', '226.99', '229.00', '508.94', '508.94', '508.94', '557.03', '626.41']
# 475
# ['97.95', '104.99', '109.00', '116.18', '118.75', '119.15', '120.95', '123.62', '129.99', '129.99', '130.00', '147.93', '149.95', '157.89', '168.98', '207.70', '324.91']
# 478
# ['129.99', '269.97', '339.99', '349.99']
# 481
# ['86.99', '119.99', '119.99']
# 484
# ['74.55', '79.85', '79.99', '223.90']
# 487
# ['69.99', '479.99']
# 490
# ['55.59', '59.99', '64.99', '64.99', '74.88', '79.95']
# 499
# ['52.88', '64.99', '85.00', '500.00']
# 502
# ['469.99', '499.99', '699.99', '899.99']
# 505
# ['85.00', '110.00', '499.99']
# 508
# ['209.00']
# 511
# ['349.00']
# 514
# ['475.99', '511.82', '518.88', '525.93', '535.99', '555.99', '555.99', '557.76', '559.99', '581.00', '599.32', '635.95', '669.99', '669.99', '854.99', '854.99', '888.99', '889.00', '889.99', '912.46', '912.76', '1044.00', '1065.99', '1099.95', '1105.99', '1134.00', '1282.17', '1399.99']
# 517
# ['519.99', '540.90', '540.90', '550.99', '559.99', '574.81', '574.81', '599.90', '601.43', '605.81', '605.81', '606.96', '615.00', '698.81', '793.64']
# 520
# ['247.99', '247.99', '254.58', '268.00', '282.00', '285.00', '285.00', '339.99', '355.95']
# 523
# ['174.04', '175.15', '179.00', '182.99', '238.98']
# 526
# ['124.90', '124.90', '155.00', '155.00']
# 529
# ['396.00', '399.99', '419.99', '419.99', '432.00', '439.99', '449.99', '479.99', '539.99', '598.99', '599.99', '617.99', '674.70', '806.33', '1499.99', '1699.99']
# 532
# ['90.25', '91.92', '115.95', '139.99', '173.99']
# 535
# ['139.99', '149.99', '189.00', '189.00', '189.81', '190.00', '201.09', '219.90', '219.99', '227.00', '249.00', '249.00', '335.99', '335.99', '349.99', '376.99', '376.99', '376.99', '399.00']
# 538
# ['289.99', '289.99', '299.99', '299.99', '349.00', '573.11', '579.59', '585.14', '624.98', '751.01', '964.55']
# 541
# ['259.99', '260.00', '329.00', '376.72', '402.64', '406.61', '591.47', '591.47', '611.14', '611.14']
# 544
# ['107.99', '127.74', '139.99', '144.98', '145.99', '145.99', '149.99', '149.99', '150.96', '154.99', '163.99', '163.99', '165.99', '169.00', '211.97', '234.96', '278.99', '278.99']
# 547
# ['144.98', '149.99', '152.34']
# 550
# ['99.98']
# 553
# ['319.99', '367.94', '578.50']
# 556
# ['119.99', '130.71', '237.15']
# 559
# ['159.99', '220.99', '240.95', '240.95', '252.95', '252.95', '374.80', '450.73']
# 562
# ['152.00', '152.00', '152.99', '154.86', '154.89', '154.99', '154.99', '174.99', '187.00']
# 565
# ['192.00']
# 568
# ['89.99']
# 571
# ['106.95', '190.44']
# 574
# ['259.99', '297.99', '297.99']
# 577
# ['40.99', '194.00']
# 580
# ['109.99', '141.95', '141.95', '193.11', '193.11']
# 583
# ['176.83']
# 586
# ['472.06', '542.78', '548.56', '696.67', '719.39']
# 589
# ['189.99', '199.95']
# 592
# ['199.95', '199.97']
# 595
# ['109.47', '109.59', '149.52']
# 598
# ['259.99', '292.98']
# 601
# ['154.99', '162.15']
# 604
# ['402.99']
# 607
# ['239.99']
# 610
# ['146.99', '155.98', '159.99', '169.61']
# 613
# ['130.30', '133.44', '197.40', '249.00']
# 616
# ['99.99', '114.67', '115.98', '119.28', '119.30', '180.84', '253.99', '269.99', '304.95', '304.95', '309.95', '309.95', '397.95', '419.05']
# 619
# ['126.54']
# 622
# ['127.99']
# 625
# ['85.00']
# 628
# ['144.98', '145.99', '145.99', '163.99', '174.04', '175.00', '175.15', '182.99', '183.63']
# 631
# ['219.87']
# 634
# ['275.94']
# 637
# ['54.25', '63.80', '89.95']
# 640
# ['112.96', '130.95']
# 643
# ['713.00']
# 646
# ['209.55']
# 649
# ['849.90']
# 652
# ['153.95', '156.71', '159.95', '159.95', '159.95', '169.95', '491.00']
# 655
# ['69.39', '76.83']
# 658
# ['84.99', '94.99']
# 661
# ['262.09', '264.57', '275.10']
# 664
# ['139.99', '250.18']
# 670
# ['410.00', '410.00']
# 673
# ['57.95', '124.99', '139.99']
# 676
# ['399.99', '399.99', '409.99', '414.00', '415.00', '419.99', '448.96', '454.00', '804.59', '963.05']
# 679
# ['202.00', '264.90']
# 682
# ['420.00', '627.45', '643.00', '1499.99']
# 685
# ['144.84', '199.00', '229.99', '278.00', '325.99']
# 688
# ['192.00', '196.47', '199.99', '236.87', '239.72', '247.38', '247.39', '329.00', '392.00', '499.00']
# 691
# ['149.99', '379.00']
# 694
# ['216.29', '217.90', '285.00', '520.00']
# 697
# ['71.99', '116.10', '219.00', '701.10']
# 700
# ['76.45', '98.55', '118.00', '119.95', '167.19', '199.00', '245.90', '249.99', '249.99', '349.98']
# 703
# ['689.00', '689.00', '689.00', '689.00', '689.00', '745.00', '759.00']
# 706
# ['109.99', '162.00', '179.89', '192.14', '192.14', '237.59', '237.59', '375.00', '379.00', '379.00', '649.99']
# 709
# ['357.40', '381.29', '389.28', '469.00', '470.90', '499.00', '549.00', '599.00', '599.00']
# 712
# ['69.95', '131.99']
# 715
# ['55.00', '55.00', '59.99', '66.00', '66.17', '68.00', '68.00', '69.99', '76.00', '76.00', '129.99']
# 718
# ['131.79', '350.00']
# 721
# ['120.00', '132.89', '145.00', '159.99', '169.99', '239.00', '349.00', '599.99']
# 724
# ['59.95', '60.00', '72.69', '74.99', '79.75', '89.10', '150.00', '179.00']
# 727
# ['51.98', '69.00', '85.99', '98.99', '127.99', '162.49', '167.33', '849.00', '850.00', '1800.00']
# 730
# ['59.00', '78.00', '79.88', '99.98']
# 733
# ['299.00', '429.00']
# 736
# ['120.00', '139.00']
# 739
# ['64.99', '149.99', '149.99', '149.99']
# 742
# ['69.99', '259.00', '259.00']
# 745
# ['57.00', '69.95', '79.99', '99.99']
# 748
# ['60.00', '65.44', '69.99', '89.00', '93.67', '96.79', '99.99', '233.75', '349.99', '459.00']
# 751
# ['59.36', '59.36', '69.99', '98.80', '229.99']
# 754
# ['65.99', '86.94']
# 757
# ['149.95']
# 760
# ['59.99', '99.00']
# 763
# ['306.00', '357.95', '357.95', '399.99', '399.99', '399.99', '399.99', '399.99', '399.99']
# ['54.99', '54.99', '54.99', '55.27', '55.27', '55.27', '55.50', '59.99', '59.99', '75.09', '87.21', '113.99']
# 826
# ['199.99', '216.95', '227.95', '279.99', '300.40', '335.00']
# 829
# ['81.63', '83.13', '83.13', '84.99', '89.00', '99.99', '99.99', '100.69']
# 832
# ['136.95', '149.59', '168.00', '228.00', '299.99', '382.26']
# 835
# ['117.00', '117.00', '149.99', '207.95', '207.95', '207.95', '230.99', '249.99', '249.99', '249.99', '249.99', '249.99', '251.99', '259.99', '329.99']
# 838
# ['219.99', '220.00', '249.95', '249.95', '249.95', '269.99', '329.99', '329.99', '329.99', '329.99', '329.99', '329.99', '329.99', '332.63', '350.00', '429.00', '432.00', '444.00']
# 841
# ['90.70', '107.95', '107.95']
# 844
# ['53.65', '54.98', '54.99', '58.50', '59.99', '62.93', '62.93', '79.99']
# 847
# ['97.68', '99.99', '145.00', '149.50', '162.95', '162.95', '162.95', '169.99', '182.38', '202.32']
# 850
# ['58.50', '82.52', '82.52', '92.53']
# 853
# ['79.20', '96.55']
# 856
# ['47.47', '48.08', '56.27', '56.92', '56.92', '69.99', '99.99', '129.99']
# 859
# ['179.55', '192.99', '195.99', '195.99', '209.00', '216.19', '223.95', '223.95', '223.95', '235.99', '235.99', '259.99', '259.99', '259.99', '259.99', '262.06', '265.49', '265.99', '289.99', '489.97']
# 862
# ['58.50']
# 865
# ['94.99', '101.74', '101.74', '101.74', '109.99', '122.00', '122.00', '139.99', '139.99', '139.99', '139.99', '139.99', '139.99', '139.99', '171.99']
# 868
# ['105.00']
# 871
# ['87.42']
# 874
# ['157.00', '183.95', '189.99', '204.95', '204.95', '209.99', '209.99', '214.99', '214.99', '225.99']
# 877
# ['97.62', '102.90', '105.00', '143.95', '143.95', '143.95', '143.95', '370.50']
# 880
# ['80.40']
# 883
# ['58.50', '74.18']
# 886
# ['56.16']
# 889
# ['71.58', '71.58', '102.95']
# 892
# ['99.99', '113.00', '113.00', '119.99', '132.95', '132.95', '132.95', '149.99', '149.99', '149.99', '159.00', '229.99']
# 895
# ['134.41']
# 898
# ['127.49', '139.99', '151.00', '151.00', '159.95', '159.95', '159.95', '169.99', '169.99', '169.99', '169.99', '170.99', '219.00']
# 901
# ['52.25']
# 904
# ['44.40']
# 907
# ['52.06', '69.75']
# 910
# ['83.71', '87.20', '139.00']
# 913
# ['82.34']
# 916
# ['85.11', '85.11', '85.11', '85.11']
# 919
# ['61.73']
# 922
# ['142.43', '199.99']
# 925
# ['149.99']
# 928
# ['129.95', '129.99', '129.99', '129.99', '135.97', '149.88']
# 931
# ['85.99', '104.95', '104.95', '107.99', '107.99', '109.95']
# 934
# ['94.95', '98.97', '99.88', '99.88', '99.88']
# 937
# ['84.49', '84.49', '84.49', '84.49', '84.95', '84.95', '89.88', '89.88', '94.95']
# 940
# ['149.99', '154.95', '167.00', '169.95', '179.95']
# 943
# ['65.00']
# 946
# ['73.99', '73.99', '73.99', '76.97']
# 949
# ['85.99', '109.99']
# 952
# ['104.99', '118.22', '118.83', '119.95', '119.99', '122.22', '124.98', '133.00', '159.00']
# 955
# ['79.99', '80.99', '88.75', '103.99', '139.00']
# 958
# ['87.87', '89.99', '144.95', '145.95', '145.95', '179.99']
# 961
# ['189.60']
# 964
# ['109.99', '119.19', '129.99', '139.99', '209.99', '219.00']
# 967
# ['53.80']
# 970
# ['58.99', '99.99']
# 973
# ['64.99', '65.97', '72.99']
# 976
# ['54.49', '69.89', '74.50', '75.99', '76.95', '77.97', '79.99']
# 979
# ['59.95', '70.00', '75.00', '77.97']
# 982
# ['203.42']
# 985
# ['75.97', '199.99']
# 988
# ['68.97', '69.99']
# 991
# ['89.99', '98.97']
# 994
# ['145.00', '411.00']
# 997
# ['104.99', '109.99']
# 1000
# ['78.95']
# 1003
# ['91.19', '199.99']
# 1006
# ['109.99']
# 1009
# ['130.00', '159.00']
# 1012
# ['59.99']
# 1015
# ['51.99', '56.99', '59.97', '59.99']
# 1018
# ['169.99']
# 1021
# ['93.00', '179.18', '189.61', '189.99', '189.99', '270.38', '270.38', '340.81']
# 1030
# ['51.97']
# 1033
# ['165.38']
# 1036
# ['86.99']
# 1039
# ['69.99']
# 1042
# ['90.00']
# 1045
# ['51.87', '52.99', '60.00']
# 1048
# ['51.90']
# 1051
# ['51.99', '58.97', '60.00', '63.79', '74.99', '86.00', '155.00']
# 1054
# ['59.95', '59.99', '69.99', '70.00', '75.00', '77.97', '99.99']
# 1057
# ['69.99']
# 1060
# ['52.99', '68.00']
# 1063
# ['60.00']
# 1066
# ['63.74']
# 1069
# ['69.95']
# 1072
# ['109.99']
# 1075
# ['62.95']
# 1081
# ['203.42']
# 1084
# ['89.99']
# 1087
# ['54.99', '57.97']
# 1093
# ['289.88']
# 1096
# ['90.29']
# 1099
# ['79.00']
# 1102
# ['49.30', '89.24', '98.80']
# 1105
# ['83.66']
# 1108
# ['136.00', '136.00', '182.38']
# 1111
# ['105.99', '119.00', '128.63', '139.46', '172.09', '172.09']
# 1114
# ['52.80', '64.36']
# 1117
# ['117.00', '163.48', '179.99', '211.13', '246.87']
# 1120
# ['93.00', '157.03']
# 1123
# ['159.99']
# 1126
# ['46.86', '85.75', '87.24', '89.99', '132.11']
# 1129
# ['82.60', '93.00']
# 1132
# ['53.95']
# 1135
# ['49.30', '55.00']
# 1138
# ['43.90']
# 1141
# ['117.00']
# 1144
# ['64.20', '76.63']
# 1147
# ['67.58']
# 1150
# ['66.71']
# 1153
# ['134.41']
# 1156
# ['128.55']
# 1159
# ['67.59']
# 1162
# ['250.98', '274.87']
# 1165
# ['58.42', '61.43', '62.84', '87.72', '87.72']
# 1168
# ['769.00']
# 1171
# ['286.04', '299.99', '339.99', '498.95', '499.95', '539.99', '599.99', '624.99', '685.45']
# 1174
# ['515.00', '520.00', '739.89', '749.99', '759.99', '769.99', '797.50', '819.99', '839.99', '848.99']
# 1177
# ['689.00', '759.00']
# 1180
# ['320.75', '329.99', '334.00', '339.99', '339.99', '379.00', '419.99', '429.99', '429.99', '596.78']
# 1183
# ['219.99', '219.99', '224.49', '224.95', '225.00', '275.99', '283.00', '309.61', '319.98', '319.99', '497.09']
# 1186
# ['72.30', '269.00', '299.95', '349.99', '359.95', '398.89', '399.98', '399.98', '399.98', '409.99', '419.99', '798.90']
# 1189
# ['229.99']
# 1192
# ['60.80', '129.99']
# 1195
# ['87.20']
# 1198
# ['133.00', '135.10', '135.10', '139.99', '139.99', '159.99', '159.99', '165.00', '189.99', '229.99']
# 1201
# ['184.39', '184.39', '205.99', '208.99', '208.99', '209.99', '214.99', '230.74', '230.74', '236.99', '236.99', '236.99']
# 1204
# ['126.62', '139.99', '139.99', '139.99', '139.99', '159.99', '199.99']
# 1207
# ['157.18', '169.50', '174.34', '175.92', '179.99', '179.99', '274.42']
# 1210
# ['110.05']
# 1213
# ['85.99', '117.84', '216.73', '234.54']
# 1216
# ['314.19']
# 1219
# ['161.65']
# 1222
# ['278.00']
# 1225
# ['214.26']
# 1231
# ['185.99', '209.99', '219.99', '219.99', '229.99']
# 1234
# ['129.99', '219.99']
# 1240
# ['64.28']
# 1243
# ['83.36']
# 1246
# ['389.08', '419.99', '422.25', '438.35', '449.99', '471.53', '532.70', '559.99', '599.99', '686.99', '699.99']
# 1249
# ['379.28', '389.00', '389.00', '389.00', '399.00', '432.94', '473.67', '499.00', '499.98', '515.99', '529.80', '557.89', '559.81', '611.53', '689.99', '698.86', '888.74']
# 1252
# ['794.14']
# 1255
# ['416.15', '429.99', '473.67', '677.14', '794.14']
# 1258
# ['519.99']
# 1261
# ['79.99', '99.90', '99.90', '129.00', '129.99', '129.99', '139.99', '159.00', '169.99', '179.99']
# 1264
# ['134.81', '134.81', '134.81', '134.81', '134.90']
# 1267
# ['81.99', '210.03']
# 1270
# ['78.90']
# 1273
# ['64.99', '159.00']
# 1276
# ['55.96']
# 1279
# ['72.95']
# 1282
# ['81.99']
# 1285
# ['135.00']
# 1288
# ['72.15', '219.00']
# 1291
# ['47.95', '49.99', '76.99', '76.99', '85.82']
# 1294
# ['99.00', '99.99']
# 1297
# ['129.99', '187.97', '240.00', '251.95', '251.95', '254.95', '254.95', '360.00']
# 1300
# ['59.99']
# 1303
# ['65.00']
# 1306
# ['139.88', '252.35']
# 1309
# ['99.99', '142.94', '148.60', '159.16', '168.00', '178.00']
# 1315
# ['158.71', '169.46', '183.94', '190.29', '191.39', '203.72']
# 1318
# ['109.99', '118.99', '119.55', '119.99', '120.95', '120.95', '120.95', '123.49', '123.49', '142.99', '142.99', '142.99', '142.99']
# 1321
# ['89.99', '96.48', '96.48', '96.48', '99.59']
# 1324
# ['149.99', '185.95', '185.95', '185.95', '189.99', '189.99', '214.99', '215.00']
# 1327
# ['86.10', '92.10', '95.63', '95.63', '95.63', '95.99']
# 1330
# ['64.99', '71.88', '71.88', '71.88', '73.99', '73.99', '74.99', '78.43', '78.43', '79.99', '79.99', '92.90', '121.05']
# 1333
# ['58.85', '59.99', '60.95', '60.95', '60.95', '60.95', '60.99', '61.95', '61.95', '65.99', '66.39', '66.39', '66.39', '69.99']
# 1336
# ['99.99', '128.99', '128.99', '134.95', '134.95', '139.99', '148.70']
# 1339
# ['119.99', '149.99', '149.99', '149.99', '151.95', '155.99', '156.99', '156.99', '159.95', '159.99', '169.99', '169.99', '169.99', '177.95', '177.95']
# 1342
# ['107.05']
# 1345
# ['89.99', '95.99', '119.99', '121.99', '129.19', '129.99', '133.95', '135.99', '135.99', '141.95', '209.19', '222.94']
# 1348
# ['149.99']
# 1351
# ['129.99', '161.49', '169.99', '169.99', '169.99', '169.99', '169.99', '173.95', '173.95', '329.75']
# 1354
# ['121.46', '139.99', '175.00', '175.99', '183.34', '192.99', '196.00', '199.49', '199.49', '199.49', '204.95', '215.99', '227.20', '229.99', '229.99', '249.99']
# 1357
# ['59.99', '60.95', '60.95', '75.57', '75.57', '75.57', '79.99', '79.99', '89.99', '89.99', '127.73', '127.73', '127.73']
# 1360
# ['55.98', '57.31', '57.31', '57.31', '64.99', '69.37', '75.90', '88.25']
# 1363
# ['70.67', '75.90', '75.90', '75.90', '75.99', '75.99', '79.99', '84.53', '84.53', '84.53', '91.80', '144.01', '144.01', '144.01', '146.98', '146.98', '146.98']
# 1366
# ['128.00', '159.99', '201.80', '205.99', '205.99', '206.14', '210.99', '210.99', '216.99', '216.99', '223.95', '223.95', '255.99', '404.89']
# 1369
# ['129.99', '139.99', '139.99', '139.99', '151.95', '151.95', '151.95', '168.95', '174.40', '189.99', '246.39', '246.39', '246.39']
# 1372
# ['52.99', '53.99', '76.20', '81.50', '94.99', '94.99', '94.99', '95.77', '95.77', '95.77', '131.39', '131.39', '131.39', '131.39', '131.39', '139.46']
# 1375
# ['75.80', '92.99', '170.95', '189.99', '191.32', '193.11']
# 1378
# ['91.80', '103.89', '103.89', '103.89', '103.89', '103.99', '106.95', '109.99', '109.99', '187.34', '189.99']
# 1381
# ['115.00', '121.95', '121.95']
# 1384
# ['87.20', '131.95', '131.95', '134.10', '246.51', '389.98']
# 1387
# ['49.30', '102.26', '128.74', '143.71', '143.71', '143.71', '221.01']
# 1390
# ['91.80', '104.95', '104.95', '105.99', '113.71', '168.62', '168.62']
# 1393
# ['75.81', '75.81', '75.81', '87.84', '163.64', '163.64', '163.64']
# 1396
# ['70.01']
# 1399
# ['72.28', '132.95']
# 1402
# ['87.51', '93.54', '139.99']
# 1405
# ['119.99', '212.28']
# 1408
# ['64.77']
# 1411
# ['128.36', '132.95', '132.95', '132.95', '133.95', '133.95']
# 1414
# ['87.20']
# 1417
# ['62.22', '99.99']
# 1420
# ['103.54', '103.54', '105.95', '105.95', '169.99']
# 1423
# ['117.84']
# 1426
# ['134.19', '196.30', '196.30', '251.01', '251.01']
# 1429
# ['101.15']
# 1432
# ['101.30']
# 1435
# ['74.43', '77.53']
# 1438
# ['104.53']
# 1444
# ['103.18', '115.01']
# 1447
# ['215.42', '275.93', '275.93', '275.93', '275.93', '275.93']
# 1450
# ['157.95']
# 1453
# ['113.59']
# 1456
# ['57.69', '59.50', '59.50']
# 1459
# ['126.95']
# 1462
# ['113.90', '113.90', '113.90', '113.90']
# 1465
# ['96.61', '109.05']
# 1468
# ['83.80', '83.80', '102.64', '102.64']
# 1471
# ['57.14']
# 1474
# ['57.14', '58.95', '179.99']
# 1621
# ['93.00', '98.99', '109.99', '109.99', '121.95', '121.95', '121.95', '191.29', '199.99', '199.99', '226.29', '274.90', '274.90', '274.90']
# 1624
# ['197.00', '210.42', '229.00', '229.99', '232.00', '232.00', '239.99', '249.95', '249.95', '296.99', '416.87']
# 1627
# ['49.30', '73.09', '74.26', '79.99']
# 1630
# ['90.99', '93.00', '94.49', '94.99', '95.29', '97.76', '132.95', '132.95', '156.00', '160.92', '164.17', '191.59', '230.00']
# 1633
# ['53.95', '58.50', '69.99', '83.43', '83.43', '83.43', '91.58', '95.99']
# 1636
# ['89.00', '89.00', '108.78', '109.00', '109.00', '128.00', '134.00', '174.95', '174.95', '179.99', '195.99', '199.99', '209.00', '225.00', '229.99', '229.99', '351.40', '351.40']
# 1639
# ['46.86', '54.06', '54.06', '54.06']
# 1642
# ['61.63', '63.28']
# 1645
# ['96.49']
# 1648
# ['44.99', '54.34']
# 1651
# ['90.32']
# 1654
# ['153.97']
# 1657
# ['121.53']
# 1660
# ['74.88']
# 1663
# ['97.62', '111.00', '224.95']
# 1666
# ['80.87']
# 1669
# ['72.77']
# 1672
# ['76.03', '76.03', '101.00', '105.95', '105.95']
# 1675
# ['107.85']
# 1678
# ['109.21', '199.00']
# 1681
# ['70.00', '77.26']
# 1684
# ['146.32']
# 1687
# ['124.87']
# 1690
# ['59.38']
# 1693
# ['164.86']
# 1696
# ['112.70', '131.32', '384.75']
# 1699
# ['60.78']
# 1702
# ['76.87', '90.60', '90.60']
# 1705
# ['90.48']
# 1708
# ['78.14', '159.99']
# 1711
# ['66.48', '100.19', '100.19', '100.19']
# 1714
# ['47.07']
# 1717
# ['50.46', '67.94', '67.94']
# 1720
# ['88.76']
# 1723
# ['55.73', '84.98', '84.98', '92.41', '98.94']
# 1726
# ['58.88', '63.45', '63.65', '63.65']
# 1729
# ['85.63', '151.95']
# 1732
# ['70.92', '132.95', '132.95']
# 1735
# ['48.49', '50.51']
# 1738
# ['99.74']
# 1741
# ['70.66', '70.66']
# 1744
# ['79.18', '82.59']
# 1747
# ['212.69']
# 1750
# ['104.95']
# 1753
# ['152.95', '162.89']
# 1756
# ['67.59', '110.95']
# 1759
# ['139.99']
# 1762
# ['69.78', '69.78', '69.78', '69.78', '69.78', '89.99']
# 1765
# ['73.99']
# 1768
# ['58.50', '58.50']
# 1771
# ['75.80']
# 1774
# ['64.20', '73.40']
# 1777
# ['112.79', '150.19', '153.99']
# 1780
# ['123.49', '163.99', '164.99', '164.99', '165.99']
# 1783
# ['79.99', '79.99', '93.99', '127.99', '128.99', '129.99', '129.99', '129.99', '129.99', '134.39']
# 1786
# ['96.81', '96.99', '126.99', '128.99', '129.99', '129.99', '153.71']
# 1789
# ['64.90', '68.99', '69.85', '78.01', '108.88', '118.58']
# 1792
# ['109.99', '146.99', '147.99', '153.99', '154.99', '155.99']
# 1795
# ['109.99']
# 1798
# ['79.19', '115.99']
# 1801
# ['139.99', '139.99', '159.99', '159.99', '189.99', '199.99']
# 1804
# ['99.99', '139.99', '169.99', '199.99', '209.99']
# 1807
# ['99.99', '99.99', '100.60', '105.99', '108.69', '109.20', '109.99', '114.95', '115.95', '115.95', '117.00', '119.99', '119.99', '119.99', '119.99', '119.99', '119.99', '128.95', '129.99', '137.14']
# 1810
# ['153.99', '169.99', '189.99', '202.72', '210.89', '217.99', '219.99', '219.99', '219.99', '219.99', '220.99', '221.99', '221.99', '222.95', '224.99', '264.50', '316.39', '321.87', '321.87']
# 1813
# ['139.99', '139.99', '139.99', '139.99', '149.99', '157.95', '159.99', '159.99', '159.99', '159.99', '161.95']
# 1816
# ['168.99', '199.99', '199.99', '229.99', '237.95', '237.95', '239.99', '239.99', '239.99', '249.99', '249.99', '249.99', '249.99', '249.99', '252.11', '288.95', '288.95', '319.99', '359.38', '379.00']
# 1819
# ['69.99', '69.99', '81.42']
# 1822
# ['128.95', '137.23', '138.60', '139.99', '142.99', '142.99', '145.89', '145.99', '145.99', '147.98', '149.99', '149.99', '159.99', '161.99']
# 1825
# ['119.99', '139.99', '139.99', '169.99', '189.63', '189.99', '189.99', '189.99', '190.70', '197.99', '198.00', '215.95', '299.99']
# 1828
# ['79.99', '79.99', '79.99', '103.00', '103.00', '111.04', '117.48', '119.99', '119.99', '124.31', '178.18', '178.18']
# 1831
# ['219.99', '459.99', '459.99', '473.95', '473.95']
# 1834
# ['109.20', '150.99', '159.99', '199.99', '298.87', '369.99']
# 1837
# ['109.99', '173.75']
# 1840
# ['149.99', '171.65', '252.39', '276.95']
# 1843
# ['141.95', '143.40']
# 1846
# ['109.99', '109.99', '224.20', '230.66', '248.00']
# 1849
# ['117.20', '180.00']
# 1858
# ['201.95', '201.95', '239.02']
# 1861
# ['216.95']
# 1864
# ['139.00']
# 1867
# ['194.00', '210.00']
# 1870
# ['192.95', '195.95']
# 1873
# ['235.95', '239.95']
# 1876
# ['160.79']
# 1879
# ['131.92', '131.92']
# 1882
# ['187.10', '187.10']
# 1885
# ['123.95', '123.95']
# 1888
# ['289.47']
# 1891
# ['133.32']
# 1894
# ['539.00']
# 1897
# ['349.00']
# 1900
# ['169.99', '459.99', '591.02', '689.99', '709.06', '778.12']
# 1903
# ['83.33']
# 1906
# ['129.33', '141.95']
# 1909
# ['309.49', '325.00', '325.00', '325.00', '349.99', '349.99', '399.99']
# 1912
# ['274.99']
# 1915
# ['295.00', '604.00']
# 1918
# ['325.00']
# 1921
# ['249.99', '249.99', '249.99', '275.00', '275.00', '275.00', '275.00']
# 1924
# ['575.00', '575.00', '575.00', '699.99', '699.99']
# 1927
# ['345.00', '345.00', '345.00', '349.99', '349.99', '375.00', '375.00', '375.00', '375.00']
# 1930
# ['675.00', '675.00', '699.99', '699.99']
# 1933
# ['295.00', '295.00', '329.99', '329.99', '329.99']
# 1936
# ['299.99', '299.99']
# 1939
# ['545.00', '675.00', '675.00']
# 1942
# ['545.00', '545.00', '545.00']
# 1945
# ['127.50']
# 1948
# ['59.10', '67.37', '68.38', '69.99', '69.99', '70.51', '73.00', '79.99', '81.02', '82.13', '89.99', '98.95', '99.99', '115.99', '115.99', '115.99', '115.99', '115.99', '124.68']
# 1951
# ['113.05', '132.95', '132.95', '227.38']
# 1954
# ['72.51', '92.43']
# 1957
# ['59.18', '84.91', '86.45', '86.83']
# 1960
# ['205.40']
# 1963
# ['244.80']
# 1966
# ['174.20']
# 1969
# ['272.90']
# 1972
# ['197.90', '231.90']
# 1975
# ['155.00']
# 1978
# ['175.00']
# 1981
# ['101.88', '109.99', '119.99', '128.99', '132.53', '138.99', '255.90']
# 1984
# ['109.99']
# 1987
# ['99.99', '110.22']
# 1990
# ['155.84']
# 1993
# ['81.40']
# 1996
# ['141.21', '200.00']
# 1999
# ['151.92']
# 2002
# ['689.99']
# 2005
# ['85.13', '129.43']
# 2008
# ['109.99', '124.99', '178.00']
# 2011
# ['84.99', '85.13', '86.81', '96.25', '119.99', '169.58']
# 2014
# ['89.99', '123.51', '125.38', '139.99', '159.21']
# 2017
# ['84.99', '94.99', '160.99']
# 2020
# ['74.99', '93.99', '97.87', '97.88', '97.99', '99.99', '99.99', '102.29', '103.04', '108.95', '108.95', '110.34', '114.99', '114.99', '117.99', '144.67', '159.99', '160.44']
# 2023
# ['649.99', '740.00', '830.00', '899.95', '1050.00', '1080.00', '1080.00', '1080.00', '1199.00', '1212.00', '1379.00']
# 2026
# ['599.95', '799.00', '877.00', '877.00', '916.00', '919.00', '919.00', '919.00', '945.00', '946.98', '1004.00', '1069.00', '1069.00', '1149.00']
# 2029
# ['299.00', '349.99', '359.99', '429.99', '464.99', '489.00', '492.00', '510.00', '629.00', '629.00', '629.00']
# 2032
# ['271.60', '319.00', '319.99', '329.95', '329.99', '359.95', '529.00', '529.00', '529.00']
# 2035
# ['359.99', '369.95', '374.99', '422.99', '434.99', '435.12', '455.75', '536.40', '593.00', '601.00', '602.00', '859.00', '864.00']
# 2038
# ['313.89', '349.99', '417.99', '503.00', '504.00', '610.00', '610.00', '720.00']
# 2041
# ['219.99', '239.88', '259.95', '265.00', '285.98', '285.99', '286.13', '286.20', '286.20', '292.49', '299.99', '305.99', '435.00', '520.00']
# 2044
# ['175.99', '212.99', '214.15', '214.20', '214.20', '214.20', '217.49', '217.49', '224.99', '224.99', '290.00', '428.00', '442.00']
# 2047
# ['141.95', '149.99', '151.15', '151.19', '151.20', '155.99', '163.79', '163.79', '168.47', '168.47', '176.88', '297.00', '297.00', '310.00', '310.00', '378.43']
# 2050
# ['89.95', '89.95', '135.00', '155.99', '339.99']
# 2053
# ['330.00']
# 2056
# ['52.09']
# 2059
# ['84.24']
# 2062
# ['64.20', '74.93']
# 2065
# ['66.91']
# 2068
# ['44.09', '44.09', '59.13']
# 2071
# ['94.87', '96.99', '108.98', '109.98', '125.00', '142.49', '143.44', '159.99']
# 2074
# ['99.98', '99.99', '99.99', '135.00']
# 2077
# ['74.99']
# 2080
# ['76.99', '76.99', '86.54', '109.00', '116.99']
# 2083
# ['78.80', '78.80']
# 2086
# ['83.43', '94.50', '94.50']
# 2089
# ['243.09']
# 2092
# ['283.00']
# 2095
# ['78.95', '78.95', '78.95', '96.99', '159.99', '197.50']
# 2098
# ['40.78']
# 2101
# ['57.40', '57.61', '68.56', '68.56', '68.79', '68.99', '69.83', '84.99', '94.24', '94.99', '99.99', '104.95', '104.95']
# 2104
# ['96.92', '114.95', '114.95']
# 2107
# ['75.80', '78.99', '84.99', '121.43', '146.99', '146.99', '146.99']
# 2110
# ['56.56', '56.56', '56.99', '56.99', '69.99', '74.75', '74.95', '75.00', '75.00', '76.77', '76.99', '79.99', '79.99', '85.62', '96.55', '108.17', '108.17']
# 2113
# ['50.05', '50.05', '56.04', '61.74', '66.99', '69.99', '69.99', '81.47', '89.94', '107.99', '133.93']
# 2116
# ['50.15', '59.62', '59.84', '59.84', '59.99', '75.80', '75.80', '85.04', '85.04', '85.04', '89.99', '125.99', '125.99', '129.47', '129.47', '129.47', '149.89']
# 2119
# ['87.47', '99.25', '99.25', '99.59', '99.95', '99.99', '117.00', '129.99', '153.95', '153.95', '153.95', '169.99', '179.34', '179.99', '189.99', '255.14', '255.14', '298.89', '298.89']
# 2122
# ['70.00', '133.95', '135.95', '135.95', '139.99', '149.37']
# 2125
# ['149.99', '156.00', '161.95', '161.95', '184.00', '189.05', '197.85']
# 2128
# ['49.30', '54.02', '57.53', '57.53', '64.36', '67.99', '69.99']
# 2131
# ['90.70', '95.99', '118.95']
# 2134
# ['49.30', '65.98', '65.99', '69.99', '73.52', '73.52', '73.52', '75.09', '79.99', '89.75']
# 2137
# ['89.99', '95.69', '105.00', '105.99', '106.46', '106.49', '106.49', '154.75', '157.24', '169.99', '178.99', '179.99']
# 2140
# ['51.00', '59.68']
# 2143
# ['105.00', '125.09', '139.00', '142.95', '142.95', '142.95', '168.75', '189.99']
# 2146
# ['59.99', '66.66', '66.99', '66.99', '67.20', '79.99', '88.99', '96.75', '173.26']
# 2149
# ['81.50']
# 2152
# ['58.37', '104.99']
# 2155
# ['51.00']
# 2158
# ['111.00']
# 2161
# ['43.81', '66.26']
# 2164
# ['65.40', '83.99']
# 2167
# ['86.10', '102.90']
# 2170
# ['56.16', '87.05']
# 2173
# ['56.47', '56.47', '59.99', '69.78', '75.24', '75.99', '85.44', '85.44', '85.44', '89.20']
# 2176
# ['57.40']
# 2179
# ['125.44']
# 2182
# ['66.60', '88.79', '152.91']
# 2185
# ['49.30', '77.68']
# 2188
# ['61.63', '67.70', '89.49', '94.93', '206.29']
# 2191
# ['52.20', '64.32', '64.32']
# 2194
# ['118.95', '118.95']
# 2197
# ['899.00']
# 2200
# ['99.00', '299.00']
# 2203
# ['89.00']
# 2206
# ['100.95']
# 2209
# ['274.99', '279.50']
# 2212
# ['60.00']
# 2215
# ['186.60', '186.70']
# 2218
# ['190.90', '218.00', '224.00', '258.90', '264.81', '288.90', '289.00']
# 2221
# ['265.40', '265.40', '328.49']
# 2224
# ['298.90', '299.00', '339.99', '341.26', '344.69', '353.00', '403.39']
# 2227
# ['110.00', '112.80', '112.90', '138.58', '145.69', '145.79']
# 2230
# ['995.00']
# 2233
# ['188.80', '189.00', '206.16', '207.00', '207.99', '212.00', '212.99', '259.99', '264.68', '290.09']
# 2236
# ['488.40', '488.50', '489.00', '542.00', '542.00', '542.00', '544.66', '563.62']
# 2239
# ['127.00', '127.00', '142.00', '152.99', '182.35', '215.00']
# 2242
# ['188.59', '189.50', '189.99', '192.13', '249.99', '500.00']
# 2245
# ['277.98', '278.52', '286.88', '286.99', '286.99', '326.04', '329.97', '331.99', '354.99', '462.00', '462.00']
# 2248
# ['113.39', '116.54', '135.90', '150.95', '153.58', '199.99', '203.30', '249.99', '401.90']
# 2251
# ['99.00', '114.95']
# 2254
# ['184.79', '184.79', '189.95', '259.00', '352.00']
# 2257
# ['152.88', '152.99', '153.00', '153.00', '153.59', '155.99', '174.84', '229.99', '232.99', '234.99', '235.99', '239.99', '242.99', '249.99', '288.49']
# 2260
# ['99.10', '99.58', '110.47', '120.99', '138.35', '155.99', '216.19']
# 2263
# ['99.99', '99.99', '115.98', '133.34', '139.49']
# 2266
# ['69.99', '79.99', '84.99', '89.99', '99.99', '99.99', '124.00']
# 2269
# ['99.99', '100.00', '393.90', '393.90']
# 2272
# ['137.99', '146.45', '148.97', '148.98', '148.99', '159.99', '199.99', '219.99']
# 2275
# ['88.88']
# 2278
# ['125.59', '129.00', '129.99', '142.79', '148.44', '176.57']
# 2281
# ['136.85', '138.34', '141.11', '142.07', '145.06', '148.56']
# 2284
# ['95.99', '109.19', '113.39', '115.13', '118.29', '118.85', '122.39', '122.40', '127.48', '141.74', '146.45', '148.30']
# 2287
# ['62.16', '62.99', '64.99', '97.71']
# 2290
# ['175.99']
# 2293
# ['119.99']
# 2296
# ['127.46', '149.99', '169.00', '170.10', '179.29', '299.98', '349.99', '879.00', '879.00']
# 2299
# ['395.00']
# 2302
# ['98.00', '99.43', '106.49', '117.59', '190.00', '195.00']
# 2305
# ['69.99', '69.99', '87.77', '113.99']
# 2308
# ['69.88']
# 2311
# ['109.00', '149.00', '149.00', '199.00']
# 2314
# ['98.69', '98.69', '98.69', '113.52', '113.68', '125.00', '129.90', '134.99']
# 2317
# ['159.99', '302.00', '302.00', '319.99']
# 2320
# ['78.74', '78.74', '78.74', '82.87', '92.99', '97.98', '98.79', '99.02', '101.99', '102.00', '109.99', '117.14']
# 2323
# ['89.21', '108.76']
# 2326
# ['81.99', '106.52', '106.91', '108.53', '119.19', '119.99', '120.00', '140.00']
# 2329
# ['92.00', '119.99']
# 2332
# ['169.95', '179.95']
# 2335
# ['64.60', '72.00', '72.50', '75.00', '75.00', '79.40', '96.19', '96.99', '102.99']
# 2338
# ['69.99', '69.99', '107.84', '462.00']
# 2344
# ['69.95', '106.00', '114.71', '122.00', '123.00', '129.00', '129.99', '135.00', '138.00', '139.99']
# 2347
# ['106.00', '122.00', '123.00', '129.00', '129.99', '135.00', '138.00', '139.99']
# 2350
# ['100.00']
# 2353
# ['127.46', '127.46']
# 2356
# ['72.44', '75.88', '76.64', '96.99']
# 2359
# ['59.99']
# 2362
# ['59.88', '60.04', '63.00', '67.19', '69.65', '82.96']
# 2365
# ['89.99', '99.99', '138.50', '142.93', '149.99']
# 2368
# ['99.99', '99.99', '99.99', '139.49', '150.00']
# 2371
# ['89.99']
# ['144.17', '161.49', '175.99', '183.99', '209.41', '211.34', '217.49', '235.99', '265.99', '278.00', '319.99', '355.00', '822.39']
# 8137
# ['345.71']
# 8140
# ['140.00']
# 8143
# ['209.99', '249.99', '293.99', '300.74', '334.06', '363.99', '377.17', '445.25', '464.47', '484.35', '495.99', '499.99', '535.99', '538.99']
# 8146
# ['107.99', '111.00', '119.99', '125.00', '134.99', '145.72', '166.99', '192.57', '196.99', '226.99']
# 8149
# ['108.78', '119.56', '134.99', '136.15', '139.99', '175.89']
# 8152
# ['201.72', '215.27']
# 8155
# ['87.51', '95.94', '111.01', '111.39', '114.45', '119.99', '130.10', '138.58', '164.99', '199.00']
# 8158
# ['176.99', '179.43', '450.00']
# 8161
# ['143.16', '155.47', '160.16', '195.99']
# 8164
# ['426.66', '475.98', '544.50', '989.00']
# 8167
# ['329.99', '329.99', '339.95', '348.99', '356.00', '360.00', '368.12', '369.00', '388.43', '429.93', '645.99']
# 8170
# ['300.16', '486.34', '839.00']
# 8173
# ['282.17', '699.00']
# 8176
# ['203.11', '228.43', '344.35', '359.99', '382.77', '395.24', '399.99', '406.28', '474.99']
# 8179
# ['224.99', '251.61', '285.35', '356.44', '435.99', '650.00']
# 8182
# ['123.48', '169.99', '182.82', '184.34', '194.49', '194.99', '198.06', '212.02']
# 8185
# ['119.99', '149.74']
# 8188
# ['209.12']
# 8191
# ['192.57', '245.05']
# 8194
# ['102.99', '140.03', '219.99']
# 8197
# ['89.99', '150.70', '156.54']
# 8200
# ['131.30', '135.17']
# 8203
# ['252.25']
# 8206
# ['278.16', '293.18']
# 8209
# ['123.22', '125.73', '200.24', '245.32', '319.88']
# 8212
# ['179.99', '222.69']
# 8215
# ['199.35', '208.42']
# 8218
# ['111.05', '149.47']
# 8221
# ['167.27']
# 8224
# ['89.99', '156.77']
# 8227
# ['118.99', '124.66']
# 8230
# ['259.20']
# 8233
# ['209.99']
# 8236
# ['292.70', '485.00', '499.99', '499.99', '595.37', '599.00', '599.00', '599.00', '599.99']
# 8239
# ['69.99', '156.54', '225.99', '229.99', '239.99', '254.99', '254.99', '269.58', '427.13', '427.13', '525.03', '525.03']
# 8242
# ['165.32', '174.99', '180.39', '196.26', '199.99', '202.79', '215.25', '216.00', '259.00', '265.50', '269.06', '269.99', '293.91', '304.99', '315.00', '376.32', '617.48']
# 8245
# ['416.44']
# 8248
# ['219.99', '244.99', '264.99', '489.97', '666.00', '724.50']
# 8251
# ['275.99', '555.98', '574.14', '646.00']
# 8254
# ['204.90', '208.90', '249.00', '274.90', '299.00']
# 8257
# ['169.00']
# 8260
# ['169.00']
# 8263
# ['169.00']
# 8266
# ['269.00', '269.00']
# 8269
# ['195.00']
# 8272
# ['170.00']
# 8275
# ['260.00']
# 8278
# ['199.00']
# 8281
# ['97.47']
# 8284
# ['145.00', '170.95', '170.95', '183.99', '193.00', '233.99', '315.54']
# 8287
# ['115.00', '125.99', '125.99', '136.00', '136.00', '139.39', '139.99', '139.99', '140.39', '180.99', '196.00', '207.95', '207.95', '218.94', '262.95', '269.99', '279.99', '308.70', '399.91', '399.91']
# 8290
# ['80.03', '93.21', '94.99', '96.60', '104.00', '115.99', '118.09', '121.95', '121.95', '124.99', '128.99', '147.25', '154.99', '170.99', '198.67', '198.67']
# 8293
# ['122.00', '138.00', '155.89', '170.99', '174.11']
# 8296
# ['81.50', '102.82', '122.81']
# 8299
# ['52.80', '52.80', '80.34']
# 8302
# ['67.65', '67.65', '67.65', '67.65']
# 8305
# ['88.79', '88.79', '88.79', '88.79', '88.79']
# 8308
# ['172.95']
# 8311
# ['111.95', '111.95', '111.95', '111.95', '111.95']
# 8314
# ['131.72', '306.02', '306.02']
# 8317
# ['131.95', '131.95', '131.95', '131.95', '131.95']
# 8320
# ['99.65', '99.65']
# 8323
# ['80.87']
# 8326
# ['285.73']
# 8329
# ['237.38']
# 8332
# ['281.99']
# 8335
# ['187.99']
# 8338
# ['479.99', '499.98', '505.99', '549.98', '549.98', '599.98', '670.00', '679.99', '779.99', '879.99', '999.00']
# 8341
# ['105.99', '129.99', '134.78', '148.51', '149.99', '159.99', '187.99']
# 8344
# ['148.51', '159.99', '187.99']
# 8347
# ['59.99']
# 8350
# ['59.00', '66.99', '80.41', '95.99', '129.48']
# 8353
# ['165.99', '244.03', '338.00', '338.39']
# 8356
# ['665.99', '686.19', '789.99', '869.99']
# 8359
# ['149.99', '173.99', '174.99', '230.00']
# 8362
# ['105.00', '110.00', '149.98', '230.00']
# 8365
# ['119.99']
# 8368
# ['342.00', '378.00', '579.99', '643.72', '697.36', '836.59']
# 8371
# ['107.33']
# 8374
# ['50.12', '218.48']
# 8377
# ['53.49']
# 8380
# ['62.95', '67.72', '85.87', '299.95']
# 8383
# ['54.99', '65.99', '65.99', '69.99', '71.61']
# 8386
# ['54.99', '89.99', '99.00']
# 8392
# ['134.99', '139.99', '150.69', '154.99', '159.99', '224.99', '236.45', '239.00', '247.22', '327.00', '774.27']
# 8395
# ['74.99']
# 8398
# ['76.99', '83.99']
# 8401
# ['65.00', '185.00', '197.50']
# 8404
# ['52.90', '59.99']
# 8407
# ['169.99']
# 8410
# ['118.00']
# 8413
# ['50.00', '53.99', '54.00', '54.99', '54.99', '55.00', '55.00', '59.99', '69.98', '84.99']
# 8416
# ['84.99', '87.85', '87.99', '89.99', '98.98', '99.99', '108.95', '119.99', '129.95']
# 8419
# ['84.99', '89.99', '92.97', '95.99', '99.99', '120.00', '130.02', '149.00']
# 8422
# ['225.86']
# 8425
# ['59.99']
# 8428
# ['69.99']
# 8431
# ['50.00', '56.99']
# 8434
# ['59.99', '68.95']
# 8437
# ['119.60', '167.90']
# 8440
# ['119.90']
# 8443
# ['235.00']
# 8446
# ['58.99', '59.99', '69.99', '119.99']
# 8449
# ['57.99']
# 8452
# ['99.99']
# 8455
# ['169.99']
# 8458
# ['199.88']
# 8461
# ['129.00', '129.00', '187.93', '449.00', '449.00']
# 8464
# ['54.99', '56.99', '69.99', '79.99']
# 8467
# ['79.95', '87.08', '94.95', '129.99', '250.00']
# 8470
# ['50.00']
# 8473
# ['89.95', '99.99']
# 8476
# ['259.00', '367.95', '367.95', '400.00']
# 8479
# ['86.00', '155.00']
# 8482
# ['79.96']
# 8485
# ['74.00']
# 8488
# ['61.99', '63.94', '69.99']
# 8491
# ['58.99']
# 8494
# ['134.99', '139.99', '150.69', '154.99', '159.99', '265.99']
# 8497
# ['59.50', '59.50']
# 8500
# ['89.99', '159.99']
# 8503
# ['50.00', '74.99', '109.99']
# 8506
# ['50.43', '58.99', '59.88', '59.99', '70.44', '73.75']
# 8509
# ['89.99']
# 8512
# ['207.51']
# 8515
# ['65.99', '67.99']
# 8518
# ['99.99']
# 8521
# ['59.49']
# 8527
# ['59.49']
# 8530
# ['78.99']
# 8533
# ['79.99', '99.99', '1500.00']
# 8536
# ['55.00']
# 8539
# ['79.96']
# 8542
# ['59.95']
# 8545
# ['215.98', '314.95', '316.95', '390.80']
# 8548
# ['187.76', '240.85', '270.95', '272.95', '410.00']
# 8551
# ['247.98', '272.14']
# 8554
# ['183.25']

# %%
dict = {'Brand': brand, 'Name': name, 'Dim': Dimensions, 'Weight': Weight, 'Bat': Battery, 'Blue': Bluetooth, 'CPU': CPU, 
        'Cam': Camera, 'Cores': Cores, 'Dis': Display, 'GPU': GPU, 'Memory card': Memory_cards, 'OS': OS, 'Pos': Positioning, 
        'RAM': RAM, 'SIM': SIM_card, 'SoC': SoC, 'Storage': Storage, 'USB': USB, 'Wi-Fi': Wi_Fi, 'Average price': avg_price}
df = pd.DataFrame(dict)
df
# Out:
#          Brand      Name                       Dim   Weight  \
# 0        10.or        G2                   No info  No info
# 1        10.or        D2     70.5 x 147.7 x 8.6 mm    144 g
# 2        10.or         G         76 x 155 x 8.5 mm    170 g
# 3          360        N5        76 x 152 x 8.25 mm    156 g
# 4           Q5      Plus       80 x 156.5 x 8.3 mm    175 g
# 5          360        Q5       74 x 149.5 x 8.5 mm    164 g
# 6          360       N4s    74.6 x 151.3 x 8.35 mm    169 g
# 7          360        N4       75.7 x 149 x 8.3 mm    140 g
# 8          Tab        10   238.2 x 172.2 x 9.98 mm    549 g
# 9         Jade     Primo     76.8 x 156.6 x 8.5 mm    150 g
# 10      Liquid        Z2      62.5 x 110 x 12.3 mm    110 g
# 11         AGM        A9      81.4 x 168 x 12.6 mm    251 g
# 12         AGM        X3    81.5 x 167.5 x 10.5 mm    216 g
# 13          X2        SE      83.4 x 168.5 x 14 mm    250 g
# 14          X1      mini          75 x 155 x 13 mm    189 g
# 15         AGM        A7          74 x 139 x 18 mm    255 g
# 16          A8        SE          83 x 159 x 16 mm    247 g
# 17          A8      Mini          70 x 131 x 15 mm    192 g
# 18         AGM       A1Q          83 x 158 x 16 mm    245 g
# 19         AGM        X2      83.4 x 168.5 x 14 mm    250 g
# 20         AGM        A8          83 x 159 x 16 mm    247 g
# 21         AGM        A2    73.2 x 133.2 x 14.5 mm    225 g
# 22         AGM        X1   78.7 x 163.5 x 11.88 mm    210 g
# 23          3X    (2019)    75.8 x 164.8 x 8.39 mm    178 g
# 24          3T        10     260 x 156.6 x 8.95 mm    440 g
# 25           1    (2019)     65.7 x 137.6 x 9.8 mm    134 g
# 26     Alcatel        1S     70.7 x 147.8 x 8.6 mm    146 g
# 27     Alcatel      Onyx    68.8 x 146.35 x 8.3 mm    130 g
# 28          1X    Evolve  70.62 x 147.55 x 9.05 mm    155 g
# 29     Alcatel        LX     69.6 x 148.1 x 9.4 mm    152 g
# ...        ...       ...                       ...      ...
# 2822      ZMax       Pro       89 x 156.8 x 9.8 mm    191 g
# 2823    Sonata         3      76.5 x 138.2 x 12 mm    181 g
# 2824       Duo       LTE      88 x 156.8 x 10.1 mm    202 g
# 2825      Axon         7     78.8 x 144.1 x 8.7 mm    191 g
# 2826       Max         2       88 x 155.9 x 9.8 mm    195 g
# 2827  Imperial       Max     86.9 x 156.6 x 9.5 mm    198 g
# 2828     Blade        L5     75.6 x 135.9 x 9.8 mm    185 g
# 2829      Avid      Plus      76.5 x 137.6 x 12 mm    179 g
# 2830       ZTE  Prestige    76.5 x 138.2 x 11.4 mm    164 g
# 2831       ZTE      Axon    77.3 x 146.2 x 10.3 mm    185 g
# 2832         X         2    76.4 x 137.8 x 10.2 mm    158 g
# 2833      ZMax         2    79.8 x 146.3 x 10.3 mm    185 g
# 2834       ZTE  Obsidian      72 x 130.5 x 11.2 mm    144 g
# 2835       ZTE     Maven    69.3 x 128.2 x 10.9 mm    146 g
# 2836       ZTE     Speed    69.3 x 127.9 x 11.2 mm    148 g
# 2837       ZTE       V5S     74.6 x 132.1 x 9.8 mm    180 g
# 2838       ZTE    Rapido    69.3 x 127.9 x 11.2 mm    153 g
# 2839       ZTE      ZMax       88 x 154.4 x 9.8 mm    170 g
# 2840         X      Z777     76.7 x 137.8 x 9.9 mm    158 g
# 2841   No info   No info    65.1 x 112.1 x 13.2 mm    136 g
# 2842         S       Pro    74.7 x 135.1 x 11.2 mm    169 g
# 2843   Concord        II    68.3 x 119.7 x 11.8 mm    136 g
# 2844       ZTE     Unico    70.4 x 126.4 x 11.5 mm    149 g
# 2845       ZTE      U809    69.3 x 121.6 x 11.4 mm    132 g
# 2846       ZTE  Imperial    69.3 x 144.4 x 13.2 mm    167 g
# 2847       ZTE     Flash      69.3 x 127.3 x 11 mm    160 g
# 2848       ZUK      Edge     78.2 x 135.8 x 8.4 mm    174 g
# 2849       ZUK        Z2     72.3 x 134.6 x 9.3 mm    162 g
# 2850        Z2       Pro       74 x 138.1 x 8.2 mm    158 g
# 2851       ZUK        Z1     81.2 x 147.9 x 9.8 mm    191 g
#
#                        Bat Blue  \
# 0     5000 mAh, Li-Polymer  4.2
# 1     3200 mAh, Li-Polymer  4.2
# 2     4000 mAh, Li-Polymer  4.2
# 3     4000 mAh, Li-Polymer  4.2
# 4         3700 mAh, Li-Ion  4.1
# 5         3200 mAh, Li-Ion  4.1
# 6     5000 mAh, Li-Polymer  4.1
# 7     3080 mAh, Li-Polymer  4.0
# 8               Li-Polymer  4.1
# 9     2800 mAh, Li-Polymer  4.1
# 10        1300 mAh, Li-Ion  3.0
# 11    5400 mAh, Li-Polymer  4.0
# 12    4100 mAh, Li-Polymer  5.0
# 13    6000 mAh, Li-Polymer  4.0
# 14    4000 mAh, Li-Polymer  4.0
# 15    2930 mAh, Li-Polymer  4.0
# 16    4050 mAh, Li-Polymer  4.0
# 17    2600 mAh, Li-Polymer  4.0
# 18    4050 mAh, Li-Polymer  4.0
# 19    6000 mAh, Li-Polymer  4.0
# 20    4050 mAh, Li-Polymer  4.0
# 21    2600 mAh, Li-Polymer  4.0
# 22    5400 mAh, Li-Polymer  4.0
# 23        4000 mAh, Li-Ion  4.2
# 24    4080 mAh, Li-Polymer  4.2
# 25    2000 mAh, Li-Polymer  4.2
# 26    3060 mAh, Li-Polymer  4.2
# 27    3000 mAh, Li-Polymer  4.2
# 28    2460 mAh, Li-Polymer  4.2
# 29    2460 mAh, Li-Polymer  4.1
# ...                    ...  ...
# 2822  3000 mAh, Li-Polymer  4.2
# 2823      2750 mAh, Li-Ion  4.2
# 2824      3900 mAh, Li-Ion  4.2
# 2825  3050 mAh, Li-Polymer  4.2
# 2826      3000 mAh, Li-Ion  4.2
# 2827      3100 mAh, Li-Ion  4.2
# 2828      2550 mAh, Li-Ion  4.1
# 2829      2600 mAh, Li-Ion  4.2
# 2830      2850 mAh, Li-Ion  4.2
# 2831  3500 mAh, Li-Polymer  4.1
# 2832      2980 mAh, Li-Ion  4.1
# 2833      3600 mAh, Li-Ion  4.1
# 2834      1980 mAh, Li-Ion  4.1
# 2835      2600 mAh, Li-Ion  4.1
# 2836  2500 mAh, Li-Polymer  4.1
# 2837      2800 mAh, Li-Ion  4.1
# 2838      2620 mAh, Li-Ion  4.1
# 2839      2900 mAh, Li-Ion  4.1
# 2840      2700 mAh, Li-Ion  4.1
# 2841      1500 mAh, Li-Ion  3.0
# 2842  2500 mAh, Li-Polymer  4.1
# 2843      1820 mAh, Li-Ion  4.1
# 2844      2620 mAh, Li-Ion  4.1
# 2845      1400 mAh, Li-Ion  2.1
# 2846      3100 mAh, Li-Ion  4.1
# 2847      1780 mAh, Li-Ion  4.1
# 2848  3600 mAh, Li-Polymer  4.2
# 2849  3300 mAh, Li-Polymer  4.2
# 2850  3700 mAh, Li-Polymer  4.2
# 2851  4650 mAh, Li-Polymer  4.2
#
#                                                     CPU  \
# 0     4x 1.8 GHz Kryo 260, 4x 1.6 GHz Kryo 260, Core...
# 1                    ARM Cortex-A53, 1400 MHz, Cores: 4
# 2                    ARM Cortex-A53, 2200 MHz, Cores: 8
# 3     4x 1.95 GHz ARM Cortex-A72, 4x 1.44 GHz ARM Co...
# 4           2x 2.15 GHz Kryo, 2x 1.6 GHz Kryo, Cores: 4
# 5     4x 1.8 GHz ARM Cortex-A72, 4x 1.4 GHz ARM Cort...
# 6     2x 2.0 GHz ARM Cortex-A72, 4x 1.85 GHz ARM Cor...
# 7     2x 2.0 GHz ARM Cortex-A72, 4x 1.85 GHz ARM Cor...
# 8     2x 2.0 GHz ARM Cortex-A72, 4x 1.5 GHz ARM Cort...
# 9     2x 1.8 GHz ARM Cortex-A57, 4x 1.44 GHz ARM Cor...
# 10                    ARM Cortex-A5, 1000 MHz, Cores: 1
# 11                   ARM Cortex-A53, 1800 MHz, Cores: 8
# 12    4x 2.8 GHz Kryo 385, 4x 1.8 GHz Kryo 385, Core...
# 13    4x 1.95 GHz ARM Cortex-A72, 4x 1.44 GHz ARM Co...
# 14                    ARM Cortex-A7, 1100 MHz, Cores: 4
# 15                    ARM Cortex-A7, 1100 MHz, Cores: 4
# 16                   ARM Cortex-A53, 1200 MHz, Cores: 4
# 17                    ARM Cortex-A7, 1100 MHz, Cores: 4
# 18                   ARM Cortex-A53, 1200 MHz, Cores: 4
# 19    4x 1.95 GHz ARM Cortex-A72, 4x 1.44 GHz ARM Co...
# 20                   ARM Cortex-A53, 1200 MHz, Cores: 4
# 21                    ARM Cortex-A7, 1100 MHz, Cores: 4
# 22    4x 1.5 GHz ARM Cortex-A53, 4x 1.2 GHz ARM Cort...
# 23    4x 2.0 GHz ARM Cortex-A53, 4x 1.5 GHz ARM Cort...
# 24                   ARM Cortex-A53, 1280 MHz, Cores: 4
# 25                   ARM Cortex-A53, 1300 MHz, Cores: 4
# 26    4x 1.6 GHz ARM Cortex-A55, 4x 1.2 GHz ARM Cort...
# 27                   ARM Cortex-A53, 1500 MHz, Cores: 4
# 28                   ARM Cortex-A53, 1300 MHz, Cores: 4
# 29                   ARM Cortex-A53, 1100 MHz, Cores: 4
# ...                                                 ...
# 2822  4x 1.5 GHz ARM Cortex-A53, 4x 1.2 GHz ARM Cort...
# 2823                 ARM Cortex-A53, 1200 MHz, Cores: 4
# 2824  4x 1.7 GHz ARM Cortex-A53, 4x 1.0 GHz ARM Cort...
# 2825        2x 2.15 GHz Kryo, 2x 1.6 GHz Kryo, Cores: 4
# 2826  4x 1.5 GHz ARM Cortex-A53, 4x 1.2 GHz ARM Cort...
# 2827  4x 1.7 GHz ARM Cortex-A53, 4x 1.0 GHz ARM Cort...
# 2828                 ARM Cortex-A53, 1400 MHz, Cores: 2
# 2829                 ARM Cortex-A53, 1200 MHz, Cores: 4
# 2830                 ARM Cortex-A53, 1000 MHz, Cores: 4
# 2831                      Krait 400, 2200 MHz, Cores: 4
# 2832                 ARM Cortex-A53, 1100 MHz, Cores: 4
# 2833                  ARM Cortex-A7, 1100 MHz, Cores: 4
# 2834                   ARM Cortex-A7, 900 MHz, Cores: 4
# 2835                  ARM Cortex-A7, 1100 MHz, Cores: 4
# 2836                  ARM Cortex-A7, 1300 MHz, Cores: 4
# 2837                  ARM Cortex-A7, 1100 MHz, Cores: 4
# 2838                      Krait 200, 1300 MHz, Cores: 2
# 2839                 ARM Cortex-A53, 1300 MHz, Cores: 4
# 2840                 ARM Cortex-A53, 1300 MHz, Cores: 4
# 2841                   ARM Cortex-A5, 900 MHz, Cores: 1
# 2842                      Krait 400, 2200 MHz, Cores: 4
# 2843                 ARM Cortex-A53, 1300 MHz, Cores: 2
# 2844                      Krait 200, 1100 MHz, Cores: 2
# 2845                 ARM Cortex-A53, 1300 MHz, Cores: 2
# 2846                          Krait, 1300 MHz, Cores: 2
# 2847                          Krait, 1400 MHz, Cores: 2
# 2848        2x 2.35 GHz Kryo, 2x 2.0 GHz Kryo, Cores: 4
# 2849        2x 2.15 GHz Kryo, 2x 1.6 GHz Kryo, Cores: 4
# 2850        2x 2.15 GHz Kryo, 2x 1.6 GHz Kryo, Cores: 4
# 2851                      Krait 400, 2400 MHz, Cores: 4
#
#                                                  Cam    Cores  \
# 0     4608 x 3456 pixels, 3840 x 2160 pixels, 30 fps  No info
# 1     4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps  No info
# 2     4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps  No info
# 3     4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps  No info
# 4     4160 x 3120 pixels, 3840 x 2160 pixels, 30 fps  No info
# 5     4160 x 3120 pixels, 3840 x 2160 pixels, 30 fps  No info
# 6     5312 x 2988 pixels, 1920 x 1080 pixels, 30 fps  No info
# 7     4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps  No info
# 8     2624 x 1968 pixels, 1920 x 1080 pixels, 30 fps  No info
# 9     5344 x 4016 pixels, 3840 x 2160 pixels, 30 fps  No info
# 10                                2048 x 1536 pixels  No info
# 11    4000 x 3000 pixels, 1920 x 1080 pixels, 30 fps  No info
# 12    4032 x 3024 pixels, 1920 x 1080 pixels, 30 fps  No info
# 13    4000 x 3000 pixels, 1920 x 1080 pixels, 30 fps  No info
# 14     3264 x 2448 pixels, 1280 x 720 pixels, 30 fps  No info
# 15     3264 x 2448 pixels, 1280 x 720 pixels, 30 fps  No info
# 16     3264 x 2448 pixels, 1280 x 720 pixels, 30 fps  No info
# 17     3264 x 2448 pixels, 1280 x 720 pixels, 30 fps  No info
# 18     4160 x 3120 pixels, 1280 x 720 pixels, 30 fps  No info
# 19    4000 x 3000 pixels, 1920 x 1080 pixels, 30 fps  No info
# 20     4160 x 3120 pixels, 1280 x 720 pixels, 30 fps  No info
# 21     3264 x 2448 pixels, 1280 x 720 pixels, 30 fps  No info
# 22    4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps  No info
# 23    4608 x 3456 pixels, 1920 x 1080 pixels, 30 fps  No info
# 24     1600 x 1200 pixels, 1280 x 720 pixels, 30 fps  No info
# 25    2592 x 1944 pixels, 1920 x 1080 pixels, 30 fps  No info
# 26    4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps  No info
# 27    4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps  No info
# 28    3264 x 2448 pixels, 1920 x 1080 pixels, 30 fps  No info
# 29     3264 x 2448 pixels, 1280 x 720 pixels, 30 fps  No info
# ...                                              ...      ...
# 2822  4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps  No info
# 2823   2592 x 1944 pixels, 1280 x 720 pixels, 30 fps  No info
# 2824  4096 x 3072 pixels, 1920 x 1080 pixels, 30 fps  No info
# 2825  5952 x 3348 pixels, 3840 x 2160 pixels, 30 fps  No info
# 2826  4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps  No info
# 2827  4096 x 3072 pixels, 1920 x 1080 pixels, 30 fps  No info
# 2828   2592 x 1944 pixels, 1280 x 720 pixels, 30 fps  No info
# 2829   2592 x 1944 pixels, 1280 x 720 pixels, 30 fps  No info
# 2830   2592 x 1944 pixels, 1280 x 720 pixels, 30 fps  No info
# 2831  4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps  No info
# 2832  3264 x 2448 pixels, 1920 x 1080 pixels, 30 fps  No info
# 2833  3264 x 2448 pixels, 1920 x 1080 pixels, 30 fps  No info
# 2834   2560 x 1920 pixels, 1280 x 720 pixels, 30 fps  No info
# 2835   2592 x 1944 pixels, 1280 x 720 pixels, 30 fps  No info
# 2836   2592 x 1944 pixels, 1280 x 720 pixels, 30 fps  No info
# 2837  4128 x 3096 pixels, 1920 x 1080 pixels, 30 fps  No info
# 2838                              3264 x 2448 pixels  No info
# 2839  3264 x 2448 pixels, 1920 x 1080 pixels, 30 fps  No info
# 2840   2592 x 1944 pixels, 1280 x 720 pixels, 30 fps  No info
# 2841            1600 x 1200 pixels, 640 x 480 pixels  No info
# 2842  4128 x 3096 pixels, 1920 x 1080 pixels, 30 fps  No info
# 2843   2592 x 1944 pixels, 1280 x 720 pixels, 30 fps  No info
# 2844   2592 x 1944 pixels, 1280 x 720 pixels, 30 fps  No info
# 2845                              1600 x 1200 pixels  No info
# 2846           2592 x 1944 pixels, 1280 x 720 pixels  No info
# 2847  4000 x 3000 pixels, 1920 x 1080 pixels, 30 fps  No info
# 2848  4160 x 3120 pixels, 3840 x 2160 pixels, 30 fps  No info
# 2849  4160 x 3120 pixels, 3840 x 2160 pixels, 30 fps  No info
# 2850  4160 x 3120 pixels, 3840 x 2160 pixels, 30 fps  No info
# 2851  4160 x 3120 pixels, 1920 x 1080 pixels, 30 fps  No info
#
#                                                    Dis  ...  \
# 0             6.18 in, IPS, 1080 x 2246 pixels, 24 bit  ...
# 1              5.45 in, IPS, 720 x 1440 pixels, 24 bit  ...
# 2              5.5 in, IPS, 1080 x 1920 pixels, 24 bit  ...
# 3              5.5 in, IPS, 1080 x 1920 pixels, 24 bit  ...
# 4       6 in, Super AMOLED, 1080 x 1920 pixels, 24 bit  ...
# 5     5.5 in, Super AMOLED, 1080 x 1920 pixels, 24 bit  ...
# 6              5.5 in, IPS, 1080 x 1920 pixels, 24 bit  ...
# 7              5.5 in, IPS, 1080 x 1920 pixels, 24 bit  ...
# 8              9.7 in, IPS, 2048 x 1536 pixels, 24 bit  ...
# 9           5.5 in, AMOLED, 1080 x 1920 pixels, 24 bit  ...
# 10               3.5 in, TFT, 320 x 480 pixels, 18 bit  ...
# 11            5.99 in, IPS, 1080 x 2160 pixels, 24 bit  ...
# 12            5.99 in, TFT, 1080 x 2160 pixels, 24 bit  ...
# 13          5.5 in, AMOLED, 1080 x 1920 pixels, 24 bit  ...
# 14                5 in, TFT, 720 x 1280 pixels, 24 bit  ...
# 15                 4 in, TFT, 480 x 800 pixels, 24 bit  ...
# 16                5 in, IPS, 720 x 1280 pixels, 24 bit  ...
# 17                 4 in, TFT, 480 x 800 pixels, 24 bit  ...
# 18                5 in, IPS, 720 x 1280 pixels, 24 bit  ...
# 19          5.5 in, AMOLED, 1080 x 1920 pixels, 24 bit  ...
# 20                5 in, IPS, 720 x 1280 pixels, 24 bit  ...
# 21                 4 in, TFT, 480 x 800 pixels, 24 bit  ...
# 22    5.5 in, Super AMOLED, 1080 x 1920 pixels, 24 bit  ...
# 23             6.52 in, IPS, 720 x 1600 pixels, 24 bit  ...
# 24               10 in, IPS, 1280 x 800 pixels, 24 bit  ...
# 25                 5 in, LCD, 480 x 960 pixels, 24 bit  ...
# 26              5.5 in, IPS, 720 x 1440 pixels, 24 bit  ...
# 27              5.5 in, IPS, 720 x 1440 pixels, 24 bit  ...
# 28              5.34 in, IPS, 480 x 960 pixels, 24 bit  ...
# 29              5.34 in, IPS, 480 x 960 pixels, 24 bit  ...
# ...                                                ...  ...
# 2822           6.2 in, IPS, 1080 x 2432 pixels, 24 bit  ...
# 2823           4.9 in, TFT, 1080 x 1920 pixels, 24 bit  ...
# 2824              6 in, LCD, 720 x 1520 pixels, 24 bit  ...
# 2825        5.6 in, AMOLED, 1176 x 2160 pixels, 24 bit  ...
# 2826            5.9 in, IPS, 720 x 1560 pixels, 24 bit  ...
# 2827           6.2 in, LCD, 1080 x 2160 pixels, 24 bit  ...
# 2828            4.8 in, IPS, 720 x 1440 pixels, 24 bit  ...
# 2829            4.8 in, TFT, 720 x 1440 pixels, 24 bit  ...
# 2830           4.8 in, IPS, 1080 x 2246 pixels, 24 bit  ...
# 2831           5.3 in, IPS, 1080 x 2246 pixels, 24 bit  ...
# 2832             5 in, IPS, 1080 x 2340 pixels, 24 bit  ...
# 2833            5.4 in, IPS, 720 x 1560 pixels, 24 bit  ...
# 2834           4.5 in, TFT, 1080 x 2340 pixels, 24 bit  ...
# 2835           4.3 in, TFT, 1080 x 2246 pixels, 24 bit  ...
# 2836           4.6 in, LCD, 1080 x 2400 pixels, 24 bit  ...
# 2837           4.8 in, IPS, 1080 x 2246 pixels, 24 bit  ...
# 2838           4.4 in, TFT, 1080 x 1920 pixels, 24 bit  ...
# 2839           5.9 in, TFT, 1080 x 2160 pixels, 24 bit  ...
# 2840                      5 in, LCD, 720 x 1520 pixels  ...
# 2841                   3.5 in, TFT, 1080 x 2340 pixels  ...
# 2842           5.1 in, IPS, 1176 x 2160 pixels, 24 bit  ...
# 2843              4 in, TFT, 720 x 1520 pixels, 24 bit  ...
# 2844            4.4 in, TFT, 720 x 1560 pixels, 24 bit  ...
# 2845           3.9 in, TFT, 1080 x 1920 pixels, 24 bit  ...
# 2846                   4.1 in, TFT, 1080 x 2400 pixels  ...
# 2847           4.6 in, IPS, 1176 x 2160 pixels, 24 bit  ...
# 2848           5.7 in, IPS, 1080 x 2160 pixels, 24 bit  ...
# 2849           4.8 in, IPS, 1080 x 2246 pixels, 24 bit  ...
# 2850  5.3 in, Super AMOLED, 1080 x 2400 pixels, 24 bit  ...
# 2851           5.6 in, IPS, 1176 x 2160 pixels, 24 bit  ...
#
#                         Memory card  \
# 0     microSD, microSDHC, microSDXC
# 1     microSD, microSDHC, microSDXC
# 2     microSD, microSDHC, microSDXC
# 3     microSD, microSDHC, microSDXC
# 4     microSD, microSDHC, microSDXC
# 5     microSD, microSDHC, microSDXC
# 6     microSD, microSDHC, microSDXC
# 7     microSD, microSDHC, microSDXC
# 8     microSD, microSDHC, microSDXC
# 9     microSD, microSDHC, microSDXC
# 10               microSD, microSDHC
# 11    microSD, microSDHC, microSDXC
# 12    microSD, microSDHC, microSDXC
# 13    microSD, microSDHC, microSDXC
# 14    microSD, microSDHC, microSDXC
# 15    microSD, microSDHC, microSDXC
# 16    microSD, microSDHC, microSDXC
# 17    microSD, microSDHC, microSDXC
# 18    microSD, microSDHC, microSDXC
# 19    microSD, microSDHC, microSDXC
# 20    microSD, microSDHC, microSDXC
# 21    microSD, microSDHC, microSDXC
# 22    microSD, microSDHC, microSDXC
# 23    microSD, microSDHC, microSDXC
# 24    microSD, microSDHC, microSDXC
# 25               microSD, microSDHC
# 26    microSD, microSDHC, microSDXC
# 27    microSD, microSDHC, microSDXC
# 28    microSD, microSDHC, microSDXC
# 29    microSD, microSDHC, microSDXC
# ...                             ...
# 2822  microSD, microSDHC, microSDXC
# 2823  microSD, microSDHC, microSDXC
# 2824  microSD, microSDHC, microSDXC
# 2825  microSD, microSDHC, microSDXC
# 2826  microSD, microSDHC, microSDXC
# 2827  microSD, microSDHC, microSDXC
# 2828             microSD, microSDHC
# 2829  microSD, microSDHC, microSDXC
# 2830             microSD, microSDHC
# 2831                        No info
# 2832  microSD, microSDHC, microSDXC
# 2833             microSD, microSDHC
# 2834  microSD, microSDHC, microSDXC
# 2835             microSD, microSDHC
# 2836             microSD, microSDHC
# 2837             microSD, microSDHC
# 2838             microSD, microSDHC
# 2839             microSD, microSDHC
# 2840  microSD, microSDHC, microSDXC
# 2841             microSD, microSDHC
# 2842  microSD, microSDHC, microSDXC
# 2843  microSD, microSDHC, microSDXC
# 2844             microSD, microSDHC
# 2845             microSD, microSDHC
# 2846             microSD, microSDHC
# 2847  microSD, microSDHC, microSDXC
# 2848                        No info
# 2849                        No info
# 2850                        No info
# 2851                        No info
#
#                                              OS                          Pos  \
# 0                              Android 8.1 Oreo          GPS, A-GPS, GLONASS
# 1                              Android 8.1 Oreo          GPS, A-GPS, GLONASS
# 2                          Android 7.1.2 Nougat          GPS, A-GPS, GLONASS
# 3             360 2.0 (Android 6.0 Marshmallow)  GPS, A-GPS, GLONASS, BeiDou
# 4             360 2.0 (Android 6.0 Marshmallow)  GPS, A-GPS, GLONASS, BeiDou
# 5             360 2.0 (Android 6.0 Marshmallow)  GPS, A-GPS, GLONASS, BeiDou
# 6             360 2.0 (Android 6.0 Marshmallow)  GPS, A-GPS, GLONASS, BeiDou
# 7                 360 (Android 6.0 Marshmallow)          GPS, A-GPS, GLONASS
# 8                                        Chrome                      No info
# 9                Microsoft Windows 10 Continuum                   GPS, A-GPS
# 10                     Android 4.1.1 Jelly Bean                   GPS, A-GPS
# 11                             Android 8.1 Oreo  GPS, A-GPS, GLONASS, BeiDou
# 12                  X OS 3.0 (Android 8.1 Oreo)  GPS, A-GPS, GLONASS, BeiDou
# 13                           Android 7.1 Nougat  GPS, A-GPS, GLONASS, BeiDou
# 14                      Android 6.0 Marshmallow                   GPS, A-GPS
# 15                      Android 6.0 Marshmallow                   GPS, A-GPS
# 16                           Android 7.0 Nougat          GPS, A-GPS, GLONASS
# 17                         Android 5.1 Lollipop                   GPS, A-GPS
# 18                           Android 7.0 Nougat          GPS, A-GPS, GLONASS
# 19                           Android 7.1 Nougat  GPS, A-GPS, GLONASS, BeiDou
# 20                           Android 7.0 Nougat          GPS, A-GPS, GLONASS
# 21                       Android 5.1.1 Lollipop                   GPS, A-GPS
# 22            X OS 1.0 (Android 5.1.1 Lollipop)  GPS, A-GPS, GLONASS, BeiDou
# 23                              Android 9.0 Pie                   GPS, A-GPS
# 24                              Android 9.0 Pie                   GPS, A-GPS
# 25                  Android 8.0 Oreo Go Edition                   GPS, A-GPS
# 26                              Android 9.0 Pie                   GPS, A-GPS
# 27                             Android 8.1 Oreo                   GPS, A-GPS
# 28                             Android 8.1 Oreo                   GPS, A-GPS
# 29                             Android 8.1 Oreo                   GPS, A-GPS
# ...                                         ...                          ...
# 2822                    Android 6.0 Marshmallow          GPS, A-GPS, GLONASS
# 2823                  Android 6.0.1 Marshmallow                   GPS, A-GPS
# 2824                     Android 5.1.1 Lollipop                   GPS, A-GPS
# 2825                  Android 6.0.1 Marshmallow          GPS, A-GPS, GLONASS
# 2826                    Android 6.0 Marshmallow          GPS, A-GPS, GLONASS
# 2827                     Android 5.1.1 Lollipop                   GPS, A-GPS
# 2828                       Android 5.1 Lollipop                   GPS, A-GPS
# 2829                     Android 5.1.1 Lollipop                   GPS, A-GPS
# 2830                     Android 5.1.1 Lollipop          GPS, A-GPS, GLONASS
# 2831                     Android 5.1.1 Lollipop          GPS, A-GPS, GLONASS
# 2832                       Android 5.1 Lollipop          GPS, A-GPS, GLONASS
# 2833                       Android 5.1 Lollipop          GPS, A-GPS, GLONASS
# 2834                       Android 5.1 Lollipop          GPS, A-GPS, GLONASS
# 2835                       Android 5.1 Lollipop          GPS, A-GPS, GLONASS
# 2836                       Android 4.4.2 KitKat                   GPS, A-GPS
# 2837                         Android 4.4 KitKat          GPS, A-GPS, GLONASS
# 2838                   Android 4.1.2 Jelly Bean                   GPS, A-GPS
# 2839                       Android 4.4.2 KitKat                   GPS, A-GPS
# 2840                     Android 4.3 Jelly Bean                   GPS, A-GPS
# 2841                     Android 4.1 Jelly Bean          GPS, A-GPS, GLONASS
# 2842                     Android 4.3 Jelly Bean          GPS, A-GPS, GLONASS
# 2843                     Android 4.3 Jelly Bean                   GPS, A-GPS
# 2844                   Android 4.1.2 Jelly Bean          GPS, A-GPS, GLONASS
# 2845                     Android 4.2 Jelly Bean                   GPS, A-GPS
# 2846                   Android 4.1.x Jelly Bean                   GPS, A-GPS
# 2847           Android 4.0.4 Ice Cream Sandwich          GPS, A-GPS, GLONASS
# 2848                         Android 7.0 Nougat                   GPS, A-GPS
# 2849                  Android 6.0.1 Marshmallow          GPS, A-GPS, GLONASS
# 2850                    Android 6.0 Marshmallow                   GPS, A-GPS
# 2851  CyanogenMod 12.1 (Android 5.1.1 Lollipop)          GPS, A-GPS, GLONASS
#
#                        RAM                            SIM  \
# 0     4 GB, 6 GB, 1333 MHz                       Nano-SIM
# 1      2 GB, 3 GB, 667 MHz                       Nano-SIM
# 2      3 GB, 4 GB, 800 MHz   Nano-SIM, Nano-SIM / microSD
# 3            6 GB, 933 MHz   Nano-SIM, Nano-SIM / microSD
# 4     4 GB, 6 GB, 1866 MHz   Nano-SIM, Nano-SIM / microSD
# 5            4 GB, 933 MHz   Nano-SIM, Nano-SIM / microSD
# 6            4 GB, 800 MHz   Nano-SIM, Nano-SIM / microSD
# 7            4 GB, 800 MHz   Nano-SIM, Nano-SIM / microSD
# 8           4 GB, 1866 MHz                        No info
# 9            3 GB, 933 MHz   Nano-SIM, Nano-SIM / microSD
# 10         512 MB, 200 MHz                       Mini-SIM
# 11     3 GB, 4 GB, 933 MHz   Nano-SIM / microSD, Nano-SIM
# 12    6 GB, 8 GB, 1866 MHz   Nano-SIM / microSD, Nano-SIM
# 13           6 GB, 933 MHz   Nano-SIM / microSD, Nano-SIM
# 14           2 GB, 533 MHz                      Micro-SIM
# 15           2 GB, 533 MHz                      Micro-SIM
# 16           2 GB, 533 MHz                       Nano-SIM
# 17           2 GB, 533 MHz                      Micro-SIM
# 18           3 GB, 533 MHz                       Nano-SIM
# 19           6 GB, 933 MHz   Nano-SIM / microSD, Nano-SIM
# 20     3 GB, 4 GB, 533 MHz                       Nano-SIM
# 21           2 GB, 533 MHz                      Micro-SIM
# 22           4 GB, 933 MHz  Nano-SIM / microSD, Micro-SIM
# 23                    4 GB   Nano-SIM / microSD, Nano-SIM
# 24                    2 GB                       Nano-SIM
# 25           1 GB, 667 MHz                       Nano-SIM
# 26                    3 GB                       Nano-SIM
# 27           2 GB, 667 MHz                       Nano-SIM
# 28           2 GB, 667 MHz                       Nano-SIM
# 29           2 GB, 667 MHz                       Nano-SIM
# ...                    ...                            ...
# 2822        2 GB, 1066 MHz                       Nano-SIM
# 2823         1 GB, 433 MHz                       Nano-SIM
# 2824         2 GB, 700 MHz                       Nano-SIM
# 2825  4 GB, 6 GB, 1999 MHz  Nano-SIM / microSD, Micro-SIM
# 2826        2 GB, 1066 MHz                       Nano-SIM
# 2827         2 GB, 700 MHz                       Nano-SIM
# 2828         1 GB, 166 MHz                      Micro-SIM
# 2829                  1 GB                      Micro-SIM
# 2830         2 GB, 666 MHz                       Nano-SIM
# 2831        2 GB, 1066 MHz                       Nano-SIM
# 2832                  2 GB                       Nano-SIM
# 2833         2 GB, 666 MHz                       Nano-SIM
# 2834         2 GB, 666 MHz                       Nano-SIM
# 2835         2 GB, 666 MHz                       Nano-SIM
# 2836         1 GB, 433 MHz                      Micro-SIM
# 2837         2 GB, 666 MHz                       Nano-SIM
# 2838         1 GB, 433 MHz                      Micro-SIM
# 2839                  2 GB                      Micro-SIM
# 2840                  1 GB                        No info
# 2841                512 MB                       Mini-SIM
# 2842        2 GB, 1066 MHz                        No info
# 2843                  1 GB                        No info
# 2844         2 GB, 666 MHz                       Nano-SIM
# 2845       256 MB, 166 MHz                       Mini-SIM
# 2846         1 GB, 400 MHz                       Mini-SIM
# 2847         2 GB, 633 MHz                       Mini-SIM
# 2848  4 GB, 6 GB, 1766 MHz                       Nano-SIM
# 2849  3 GB, 4 GB, 1999 MHz                       Nano-SIM
# 2850  4 GB, 6 GB, 1766 MHz                       Nano-SIM
# 2851        2 GB, 1066 MHz                       Nano-SIM
#
#                                       SoC                Storage  \
# 0                 Qualcomm Snapdragon 636                  64 GB
# 1         Qualcomm Snapdragon 425 MSM8917           16 GB, 32 GB
# 2     Qualcomm Snapdragon 626 MSM8953 Pro           32 GB, 64 GB
# 3     Qualcomm Snapdragon 653 MSM8976 Pro           32 GB, 64 GB
# 4         Qualcomm Snapdragon 820 MSM8996                 128 GB
# 5         Qualcomm Snapdragon 652 MSM8976                 128 GB
# 6            MediaTek Helio X20 (MT6797M)                  32 GB
# 7            MediaTek Helio X20 (MT6797M)                  32 GB
# 8                         Rockchip RK3399                  32 GB
# 9         Qualcomm Snapdragon 808 MSM8992                  32 GB
# 10        Qualcomm Snapdragon S1 MSM7227A                   4 GB
# 11                Qualcomm Snapdragon 450           32 GB, 64 GB
# 12                Qualcomm Snapdragon 845  64 GB, 128 GB, 256 GB
# 13    Qualcomm Snapdragon 653 MSM8976 Pro                  64 GB
# 14        Qualcomm Snapdragon 210 MSM8909                  16 GB
# 15        Qualcomm Snapdragon 210 MSM8909                  16 GB
# 16        Qualcomm Snapdragon 410 MSM8916                  16 GB
# 17        Qualcomm Snapdragon 210 MSM8909                  16 GB
# 18        Qualcomm Snapdragon 410 MSM8916                  32 GB
# 19    Qualcomm Snapdragon 653 MSM8976 Pro          64 GB, 128 GB
# 20        Qualcomm Snapdragon 410 MSM8916           32 GB, 64 GB
# 21        Qualcomm Snapdragon 210 MSM8909                  16 GB
# 22        Qualcomm Snapdragon 617 MSM8952                  64 GB
# 23           MediaTek Helio P23 (MT6763V)                  64 GB
# 24                       MediaTek MT8765B                  16 GB
# 25                        MediaTek MT6739                   8 GB
# 26                         Unisoc SC9863A                  32 GB
# 27                      MediaTek MT6739WW                  32 GB
# 28                        MediaTek MT6739                  16 GB
# 29                      MediaTek MT6739WM                  16 GB
2.0, Micro USB                             b, g, n, Wi-Fi Hotspot
# 21     2.0, Micro USB                             b, g, n, Wi-Fi Hotspot
# 22     2.0, Micro USB  b, g, n, n 5GHz, Dual band, Wi-Fi Hotspot, Wi-...
# 23     2.0, Micro USB               b, g, n, Wi-Fi Hotspot, Wi-Fi Direct
# 24     2.0, Micro USB  a, b, g, n, n 5GHz, Dual band, Wi-Fi Direct, W...
# 25     2.0, Micro USB  b, g, n, Wi-Fi Hotspot, Wi-Fi Direct, Wi-Fi Di...
# 26     2.0, Micro USB  b, g, n, Wi-Fi Hotspot, Wi-Fi Direct, Wi-Fi Di...
# 27     2.0, Micro USB  b, g, n, Wi-Fi Hotspot, Wi-Fi Direct, Wi-Fi Di...
# 28     2.0, Micro USB  b, g, n, Wi-Fi Hotspot, Wi-Fi Direct, Wi-Fi Di...
# 29     2.0, Micro USB  b, g, n, Wi-Fi Hotspot, Wi-Fi Direct, Wi-Fi Di...
# ...               ...                                                ...
# 2822  2.0, USB Type-C                                   b, g, a, ac 5GHz
# 2823   2.0, Micro USB                                            b, g, a
# 2824   2.0, Micro USB                                            b, g, a
# 2825  3.0, USB Type-C             a, b, g, Wi-Fi Display, a, ac 5GHz, ad
# 2826  2.0, USB Type-C                                   b, g, a, ac 5GHz
# 2827   2.0, Micro USB                                            b, g, a
# 2828   2.0, Micro USB                                        b, g, a, ad
# 2829   2.0, Micro USB                                            b, g, a
# 2830  2.0, USB Type-C                               b, g, a, ac 5GHz, ad
# 2831  2.0, USB Type-C                               b, g, a, ac 5GHz, ad
# 2832  2.0, USB Type-C                               b, g, a, ac 5GHz, ad
# 2833  2.0, USB Type-C                                   b, g, a, ac 5GHz
# 2834  2.0, USB Type-C                                   b, g, a, ac 5GHz
# 2835  2.0, USB Type-C                                   b, g, a, ac 5GHz
# 2836   2.0, Micro USB                                            b, g, a
# 2837  2.0, USB Type-C                                a, b, g, a, ac 5GHz
# 2838   2.0, Micro USB                                        b, g, a, ad
# 2839   2.0, Micro USB                                     a, b, g, a, ad
# 2840   3.0, Micro USB                                            b, g, a
# 2841  2.0, USB Type-C                                   b, g, a, ac 5GHz
# 2842  2.0, USB Type-C                                a, b, g, a, ac 5GHz
# 2843   2.0, Micro USB                                            b, g, a
# 2844  2.0, USB Type-C                                   b, g, a, ac 5GHz
# 2845   2.0, Micro USB                                            b, g, a
# 2846   2.0, Micro USB                                            b, g, a
# 2847  2.0, USB Type-C                                a, b, g, a, ac 5GHz
# 2848   3.0, Micro USB                                     a, b, g, a, ad
# 2849  2.0, USB Type-C                            a, b, g, a, ac 5GHz, ad
# 2850   3.1, Micro USB                          a, b, g, Wi-Fi Display, a
# 2851  2.0, USB Type-C                                a, b, g, a, ac 5GHz
#
#      Average price
# 0           262.63
# 1           185.00
# 2           262.63
# 3           197.11
# 4           463.27
# 5           317.18
# 6           231.13
# 7           168.22
# 8           340.35
# 9            92.59
# 10          249.00
# 11          272.55
# 12          665.48
# 13          403.67
# 14          124.48
# 15          145.02
# 16          126.30
# 17           91.00
# 18          165.99
# 19          542.14
# 20          170.09
# 21          139.62
# 22          232.83
# 23          169.99
# 24          198.00
# 25           69.90
# 26          118.16
# 27           65.76
# 28           85.74
# 29          149.00
# ...            ...
# 2822        128.39
# 2823         50.00
# 2824         94.97
# 2825        348.72
# 2826        120.50
# 2827         79.96
# 2828         74.00
# 2829         65.31
# 2830         58.99
# 2831        167.77
# 2832         59.50
# 2833        124.99
# 2834         78.33
# 2835         62.25
# 2836         89.99
# 2837        207.51
# 2838         66.99
# 2839         99.99
# 2840         59.49
# 2841       No info
# 2842         59.49
# 2843         78.99
# 2844        559.99
# 2845         55.00
# 2846         79.96
# 2847         59.95
# 2848        309.67
# 2849        276.50
# 2850        260.06
# 2851        183.25
#
# [2852 rows x 21 columns]

# %%
df = df.drop(df[df['Brand'] == 'No info'].index)

# %%
df.to_csv (r'dataset.csv', index = None, header=True, sep = '\t')
