# %%
import pandas as pd
from decimal import Decimal

# %%
label = set()
rf = open('information.txt', 'r')
i = 1
line = rf.readline()
while(line != ''):
    if((i%3) == 1):
        labs = line.strip().split('\t')
        for lab in labs:
            label.add(lab)
    
    i = i+1
    line = rf.readline()
rf.close()

# %%
label
# Out:
# {'Battery',
#  'Bluetooth',
#  'CPU',
#  'Camera',
#  'Cores',
#  'Dimensions',
#  'Display',
#  'GPU',
#  'Memory cards',
#  'OS',
#  'Positioning',
#  'RAM',
#  'SIM card',
#  'SoC',
#  'Storage',
#  'USB',
#  'Weight',
#  'Wi-Fi'}

# %%
Battery = []
Bluetooth = []
CPU = []
Camera = []
Cores = []
Dimensions = []
Display = []
GPU = []
Memory_cards = []
OS = []
Positioning = []
RAM = []
SIM_card = []
SoC = []
Storage = []
USB = []
Weight = []
Wi_Fi = []

rf = open('information.txt', 'r')
for m in range(i):
    line = rf.readline()
    if((m%3) == 0):
        labs = line.strip().split('\t')
    if((m%3) == 1):
        detail = line.strip().split('\t')
    if((m%3) == 2):
        if('Battery' in labs):
            index = labs.index('Battery')
            Battery.append(detail[index])
        else:
            Battery.append('No info')
    
        if('Bluetooth' in labs):
            index = labs.index('Bluetooth')
            Bluetooth.append(detail[index])
        else:
            Bluetooth.append('No info')
        
        if('CPU' in labs):
            index = labs.index('CPU')
            CPU.append(detail[index])
        else:
            CPU.append('No info')
        
        if('Camera' in labs):
            index = labs.index('Camera')
            Camera.append(detail[index])
        else:
            Camera.append('No info')
        
        if('Cores' in labs):
            index = labs.index('Cores')
            Cores.append(detail[index])
        else:
            Cores.append('No info')
        
        if('Dimensions' in labs):
            index = labs.index('Dimensions')
            Dimensions.append(detail[index])
        else:
            Dimensions.append('No info')
    
        if('Display' in labs):
            index = labs.index('Display')
            Display.append(detail[index])
        else:
            Display.append('No info')
    
        if('GPU' in labs):
            index = labs.index('GPU')
            GPU.append(detail[index])
        else:
            GPU.append('No info')
    
        if('Memory cards' in labs):
            index = labs.index('Memory cards')
            Memory_cards.append(detail[index])
        else:
            Memory_cards.append('No info')
    
        if('OS' in labs):
            index = labs.index('OS')
            OS.append(detail[index])
        else:
            OS.append('No info')
    
        if('Positioning' in labs):
            index = labs.index('Positioning')
            Positioning.append(detail[index])
        else:
            Positioning.append('No info')
    
        if('RAM' in labs):
            index = labs.index('RAM')
            RAM.append(detail[index])
        else:
            RAM.append('No info')
    
        if('SIM card' in labs):
            index = labs.index('SIM card')
            SIM_card.append(detail[index])
        else:
            SIM_card.append('No info')
        
        if('SoC' in labs):
            index = labs.index('SoC')
            SoC.append(detail[index])
        else:
            SoC.append('No info')
        
        if('Storage' in labs):
            index = labs.index('Storage')
            Storage.append(detail[index])
        else:
            Storage.append('No info')
        
        if('USB' in labs):
            index = labs.index('USB')
            USB.append(detail[index])
        else:
            USB.append('No info')
        
        if('Weight' in labs):
            index = labs.index('Weight')
            Weight.append(detail[index])
        else:
            Weight.append('No info')
        
        if('Wi-Fi' in labs):
            index = labs.index('Wi-Fi')
            Wi_Fi.append(detail[index])
        else:
            Wi_Fi.append('No info')

# %%
brand = []
name = []
avg_price = []
fo = open('name_and_price.txt', 'r')
for m in range(i):
    line = fo.readline()
    if((m%3) == 1):
        average = 0
        info = line.strip().split('\t')
        
        brand_name = info[0].split(' ')
        brand.append(brand_name[-2])
        name.append(brand_name[-1])
        
        prices = info[1].replace('$', '')
        prices = prices.split(', ')
        for price in prices:
            average += Decimal(price)
        average = average/len(prices)
        avg_price.append(round(average, 2))
# Out:
# ['10.or', '10.or', '10.or', '360', 'Q5', '360', '360', '360', 'Tab', 'Jade', 'Liquid', 'Liquid', 'AGM', 'AGM', 'X2', 'X1', 'AGM', 'A8', 'A8', 'AGM', 'AGM', 'AGM', 'AGM', 'AGM', '3X', '3T', '1', 'Alcatel', 'Alcatel', '1X', 'Alcatel', 'Alcatel', 'Alcatel', 'Alcatel', 'Alcatel', '1T', '1T', 'Alcatel', 'Alcatel', 'Alcatel', 'Alcatel', 'Alcatel', 'Alcatel', 'Alcatel', '5', 'Alcatel', 'Idol', 'A7', 'A30', 'U5', 'Alcatel', 'Idol', 'Alcatel', 'Alcatel', 'Alcatel', 'Alcatel', 'Pixi', 'Pixi', 'Shine', 'Fierce', 'Alcatel', 'Alcatel', 'OneTouch', '7', 'Pop', 'Idol', 'OneTouch', 'Pop', '3', '(4.5)', '(4.5)', 'Fierce', 'Evolve', '2', 'Pixi', '2', 'Pop', 'OneTouch', 'Idol', 'Idol', 'OneTouch', 'Alcatel', 'AllCall', 'AllCall', 'Rio', 'AllCall', 'AllCall', 'AllCall', 'AllCall', 'AllCall', 'Rio', 'AllCall', 'AllCall', 'Alldocube', 'iPlay8', 'Alldocube', 'Alldocube', 'Alldocube', 'M5', 'Alldocube', 'Alldocube', 'Alldocube', 'Alldocube', 'Power', 'Young', 'Freer', 'Alldocube', 'iPlay', 'Young', 'Alldocube', 'MIX', 'Alldocube', 'X9', 'Plus', '8', '10', '7', '8', 'HD', 'Fire', 'HD', 'Ampe', 'Pro', '11', 'iPhone', '(2019)', 'Air', '5', 'mini', '(2018)', '12.9', '(2018)', '11', 'XS', 'iPhone', 'iPhone', '(2018)', '9.7', 'iPhone', '8', 'iPhone', '2', '10.5', '9.7', '7', 'iPhone', '9.7', 'iPhone', 'mini', '6s', 'Pro', 'iPad', 'iPhone', 'Air', 'mini', '6', 'iPhone', '+', '4', 'iPhone', '3', 'iPhone', '2', 'iPhone', 'iPhone', 'iPhone', '70c', '45', 'Phone', 'ZenFone', 'Pro', 'Max', 'Lite', 'ROG', 'Live', 'Pro', 'ZenFone', '5', 'Plus', 'Pegasus', 'Zenfone', '4', '4', 'Selfie', '4', 'Max', 'Max', 'Pegasus', '10', '10', 'Max', 'Pegasus', 'Zoom', 'ZenFone', 'ZenPad', 'Max', 'Deluxe', 'Max', '10', '3', 'ZenPad', 'Pegasus', '3', 'Go', 'Asus', 'Go', 'ZenFone', 'Laser', 'Laser', 'ZenFone', '2', 'S', '2', 'ZenFone', 'ZE551ML', 'X', 'PadFone', 'ZenFone', '7', 'HD', 'Nexus', 'Key2', 'BlackBerry', 'BlackBerry', 'BlackBerry', 'BlackBerry', 'BlackBerry', 'BlackBerry', 'BlackBerry', 'Classic', 'Design', 'BlackBerry', 'Design', 'BlackBerry', 'BlackBerry', 'BlackBerry', 'BlackBerry', 'BlackBerry', 'Curve', 'Curve', 'Porsche', 'Bold', 'Torch', 'Torch', 'Curve', 'Touch', 'Touch', 'Bold', '3G', '3G', 'Blackview', 'BV9800', 'Pro', 'Blackview', 'BV9500', 'Blackview', 'Blackview', 'A60', 'BV5500', 'BV9700', 'Blackview', 'Max', 'Blackview', 'BV9600', 'Blackview', 'BV9500', 'Blackview', 'A20', 'Blackview', 'BV5800', 'Blackview', 'P10000', 'Blackview', 'Blackview', 'Blackview', 'BV9000', 'BV4000', 'Blackview', 'Blackview', 'A7', 'Blackview', 'Blackview', 'BV8000', 'R6', 'Blackview', 'P2', 'A9', 'BV7000', 'Blackview', 'Blackview', 'Blackview', 'Blackview', 'A8', 'Blackview', 'Blackview', 'Blackview', 'Blackview', 'Blackview', 'Blackview', 'Blackview', 'Omega', 'Blackview', 'Blackview', 'Vivo', 'Vivo', 'BLU', 'BLU', 'G5', 'BLU', 'BLU', 'BLU', 'BLU', 'Plus', 'Vivo', 'Vivo', 'Vivo', '5.2', 'Vivo', 'C5', 'BLU', 'Studio', 'BLU', 'Grand', 'HD', 'Studio', 'One', 'Vivo', 'Vivo', 'Pure', 'Advance', 'View', 'One', 'R2', 'Grand', 'BLU', 'Vivo', 'BLU', 'XL', 'J8', 'Grand', 'Advance', 'R2', 'Studio', 'Studio', 'Studio', '5', 'Grand', 'Grand', 'Life', 'Dash', 'Dash', 'Plus', 'Plus', 'One', 'HD', 'R1', '5.5', 'X8', 'Vivo', 'One', '5.0', 'S', 'D6', 'Bluboo', 'Bluboo', 'D5', 'Bluboo', 'Bluboo', 'Bluboo', 'Bluboo', 'Bluboo', 'Bluboo', 'Bluboo', 'Picasso', 'Bluboo', 'Maya', 'Bluboo', 'Bluboo', 'Xfire', 'Bluboo', 'Bluboo', 'Bluboo', 'BOLD', 'Cagabi', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Cat', 'Chuwi', 'Hi9', 'Hi9', 'Hi9', 'Hi8', 'Chuwi', 'Chuwi', 'Plus', 'Hi10', 'Chuwi', 'Chuwi', 'Chuwi', 'Colorfly', '3G', 'Conquest', 'Conquest', '2017', 'Conquest', 'Conquest', 'Coolpad', 'Cool', '8', 'Mega', 'Mega', 'Coolpad', 'Note', 'Play', 'Mega', 'Note', 'Coolpad', 'Coolpad', 'Play', 'Canvas', 'Coolpad', 'Changer', 'Coolpad', 'Coolpad', 'Coolpad', 'Cubot', 'R15', 'X20', 'Cubot', 'Cubot', 'Cubot', 'Quest', 'Max', 'Cubot', 'Cubot', 'Cubot', 'Cubot', 'Kong', 'J3', 'Cubot', 'Cubot', 'Cubot ...
# ['G2', 'D2', 'G', 'N5', 'Plus', 'Q5', 'N4s', 'N4', '10', 'Primo', 'Z410', 'Z2', 'A9', 'X3', 'SE', 'mini', 'A7', 'SE', 'Mini', 'A1Q', 'X2', 'A8', 'A2', 'X1', '(2019)', '10', '(2019)', '1S', 'Onyx', 'Evolve', 'LX', 'IdeaXTRA', 'Tetra', '7', '5V', '10', '7', '1C', '1X', '3X', '3V', 'Verso', '3C', 'CameoX', 'Cricket', 'U50', '5', 'Xl', 'Fierce', 'HD', 'Pulsemix', '5s', 'A50', 'IdealXCITE', 'A30', 'U5', 'Glory', 'Theatre', 'Lite', '4', 'TRU', 'Ideal', 'Flint', 'LTE', '4', '4', 'Elevate', 'Astro', '(5.5)', '4G', '3G', '2', '2', '(4)', '7', 'S', 'C7', 'Evolve', 'X', 'Ultra', "T'Pop", 'OT-903', 'S10', 'S5500', 'X', 'S1', 'Mix2', 'Madrid', 'Atom', 'Alpha', 'S', 'Rio', 'Bro', 'iPlay10Pro', 'Pro', 'M5X', 'M5XS', 'M8', 'S', 'M5', 'X', 'X1', 'KNote', 'M3', 'X5', 'X9', 'iPlay8', '10', 'X7', 'T10', 'Plus', 'iWork1X', 'U63', '4G', '(2018)', '(2017)', '(2017)', '(2017)', '10', 'Phone', '7', 'A695', 'Max', 'Pro', '11', 'Wi-Fi', '(2019)', 'Wi-Fi', '5', 'Wi-Fi', '(2018)', 'Wi-Fi', '(2018)', 'Max', 'XS', 'XR', 'Wi-Fi', '(2018)', 'X', 'Plus', '8', '12.9', 'Wi-Fi', 'Wi-Fi', 'Plus', '7', 'Wi-Fi', 'SE', '4', 'Plus', 'Wi-Fi', 'Pro', '6s', '2', '3', 'Plus', '6', '4G', 'Wi-Fi', '5', 'Wi-Fi', '4S', 'Wi-Fi', '4', '3GS', '3G', 'Xenon', 'Platinum', 'II', '6', '(M2)', '(M2)', '(L1)', 'Phone', '(L1)', '(M1)', '5Z', 'ZE620KL', '(M1)', '4S', 'V', 'Pro', 'ZE554KL', 'Pro', 'Selfie', 'ZC550TL', 'SD425', '4A', 'Z301MF', 'Z301ML', 'ZC521TL', '3S', 'ZE553KL', 'AR', 'Z10', 'ZC553KL', 'ZS550KL', 'ZC520TL', 'Z500M', 'ZE520KL', 'Z8', '3', 'ZE552KL', 'ZB551KL', 'Live', 'ZC451TG', 'Max', 'ZE600KL', 'ZE550KL', '2E', 'Plus', '8.0', 'ZE550ML', 'Zoom', 'Z3580', 'mini', 'X', '6', '2013', '7', '7', 'LE', 'Evolve', 'KEY2', 'KEYone', 'DTEK60', 'DTEK50', 'Priv', 'Leap', 'Q20', "P'9983", 'Passport', "P'9982", 'Z30', '9720', 'Q5', 'Q10', 'Z10', '9320', '9380', 'Design', '9790', '9860', '9810', '9360', '9900', '9930', '9780', '9330', '9300', 'BV9800', 'Pro', '(2019)', 'BV9100', 'Plus', 'BV6100', 'BV9600', 'Pro', 'Pro', 'Pro', 'A60', '1', 'BV5500', 'Pro', 'A30', 'Pro', 'BV9500', 'Pro', 'BV5800', 'Pro', 'A20', 'Pro', 'S6', 'P6000', 'BV9000', 'Pro', 'Pro', 'A10', 'S8', 'Pro', 'BV4000', 'A7', 'Pro', 'Lite', 'BV7000', 'Lite', 'Pro', 'Pro', 'P2', 'R6', 'E7s', 'E7', 'Max', 'BV6000s', 'R7', 'BV6000', 'A8', 'BV2000S', 'BV2000', 'BV5000', 'Pro', 'Zeta', 'Ultra', 'XL5', 'X5', 'G8', 'G6', 'Plus', 'G5', 'G9', 'C5L', 'C6L', '2019', 'XL4', 'Go', 'XI', 'HD', 'XI+', '(2018)', 'C4', 'G4', 'C6', 'M3', '(2018)', 'View', 'Plus', 'One', 'X', 'View', '5.2', 'XL', 'X3', 'Plus', 'M2', 'C5', '8L', 'S1', 'LTE', 'LTE', 'Mini', 'A4', 'LTE', 'J1', 'Mega', 'J2', 'Mini', 'X', 'M', 'Max', 'XL', 'G', '2', 'HD', 'X2', 'LTE', 'HD', 'HD', 'HD', 'XL', '(2015)', 'C', 'II', 'Pro', 'D6', 'S3', 'Pro', 'D2', 'S8+', 'S8', 'S1', 'D1', 'Dual', 'Edge', '4G', 'Mini', 'Max', 'Maya', 'Picasso', '2', 'X9', 'Xtouch', 'Xfire', 'N1', 'One', 'S52', 'S48c', 'S61', 'T20', 'S41', 'S31', 'S60', 'S50c', 'S30', 'S50', 'HiPad', 'Plus', 'Pro', 'Air', 'Air', 'Hi9', 'Hi13', 'Z8350', 'Pro', 'Hi12', 'Hi10', 'Hi8', 'G708', 'Octa', 'S12', 'S11', 'Edition', 'S8', 'S6', 'Legacy', '3', 'Lite', '5C', '5', 'Illumina', '8', '7C', '5A', '6', 'E2C', 'Splatter', '6', '4G', 'Conjr', 'S1', 'Cool1', 'Catalyst', 'Max', 'P30', 'Pro', 'Pro', 'R19', 'J7', 'J5', 'Lite', '2', 'R15', 'X19', 'A5', 'Quest', '3', 'Pro', 'J3', 'Nova', 'Power', 'P20', 'R11', 'Plus', 'Kong', 'H3', 'X18', 'Plus', 'Magic', 'R9', '2', '2', 'Manito', 'Pro', 'Echo', 'Max', 'S', 'Rainbow', 'Dinosaur', 'H2', 'CheetahPhone', 'Pro', 'S550', 'S', 'X16', 'X15', 'X12', 'X11', 'X10', '001', 'GT95', 'S308', 'S208', 'P6', 'Bobby', 'GB', 'GB', 'LTE', 'Pro', '7000', '3840', 'Pro', '8', 'Wi-Fi', '7', 'Venue', 'Pro', 'S90C', 'Lite', 'Pro', 'N100', 'Pro', 'Plus', 'Pro', 'X100', 'X90', 'N10', 'Y8C', 'S40', 'Plus', 'S90', 'Y8', 'Plus', 'X80', 'X10S', 'Lite', 'S80', 'Lite', 'Lite', 'Lite', 'S70', 'X70', 'S55', 'BL9000', 'X50', 'Lite', 'X55', 'X60L', 'S50', 'Pro', 'BL12000', '2', 'Lite', 'S30', 'BL7000', 'S60', 'X20', ...
# [Decimal('262.63'), Decimal('185.00'), Decimal('262.63'), Decimal('197.11'), Decimal('463.27'), Decimal('317.18'), Decimal('231.13'), Decimal('168.22'), Decimal('344.56'), Decimal('94.59'), Decimal('99.99'), Decimal('249.00'), Decimal('270.02'), Decimal('642.17'), Decimal('400.32'), Decimal('124.48'), Decimal('145.02'), Decimal('126.60'), Decimal('91.00'), Decimal('165.99'), Decimal('520.95'), Decimal('164.32'), Decimal('139.62'), Decimal('232.83'), Decimal('179.99'), Decimal('198.00'), Decimal('69.90'), Decimal('115.00'), Decimal('65.70'), Decimal('87.99'), Decimal('149.00'), Decimal('68.16'), Decimal('55.83'), Decimal('119.37'), Decimal('245.90'), Decimal('149.99'), Decimal('64.99'), Decimal('93.97'), Decimal('99.14'), Decimal('179.99'), Decimal('173.50'), Decimal('64.34'), Decimal('89.00'), Decimal('61.06'), Decimal('69.99'), Decimal('54.00'), Decimal('69.99'), Decimal('190.46'), Decimal('99.00'), Decimal('172.50'), Decimal('61.29'), Decimal('113.69'), Decimal('76.70'), Decimal('56.08'), Decimal('66.60'), Decimal('102.59'), Decimal('55.99'), Decimal('82.50'), Decimal('132.47'), Decimal('63.66'), Decimal('54.99'), Decimal('65.18'), Decimal('66.61'), Decimal('70.00'), Decimal('128.61'), Decimal('69.99'), Decimal('89.94'), Decimal('100.00'), Decimal('125.00'), Decimal('87.54'), Decimal('96.00'), Decimal('63.99'), Decimal('55.15'), Decimal('129.00'), Decimal('79.99'), Decimal('79.50'), Decimal('137.18'), Decimal('65.00'), Decimal('77.00'), Decimal('64.90'), Decimal('52.36'), Decimal('259.00'), Decimal('98.84'), Decimal('75.03'), Decimal('64.56'), Decimal('76.89'), Decimal('194.95'), Decimal('79.81'), Decimal('79.98'), Decimal('72.02'), Decimal('75.93'), Decimal('77.96'), Decimal('74.33'), Decimal('115.48'), Decimal('84.82'), Decimal('181.95'), Decimal('164.68'), Decimal('145.04'), Decimal('146.68'), Decimal('188.96'), Decimal('249.19'), Decimal('173.98'), Decimal('289.52'), Decimal('149.84'), Decimal('151.80'), Decimal('124.64'), Decimal('101.22'), Decimal('97.52'), Decimal('136.52'), Decimal('130.52'), Decimal('356.09'), Decimal('150.93'), Decimal('88.16'), Decimal('89.08'), Decimal('72.79'), Decimal('139.40'), Decimal('70.74'), Decimal('57.99'), Decimal('132.48'), Decimal('295.00'), Decimal('116.61'), Decimal('61.64'), Decimal('1441.59'), Decimal('1331.15'), Decimal('794.85'), Decimal('417.28'), Decimal('416.46'), Decimal('521.68'), Decimal('473.79'), Decimal('1278.52'), Decimal('1278.52'), Decimal('936.66'), Decimal('919.12'), Decimal('1091.48'), Decimal('1070.32'), Decimal('893.20'), Decimal('352.57'), Decimal('259.99'), Decimal('733.06'), Decimal('623.66'), Decimal('495.76'), Decimal('499.99'), Decimal('452.49'), Decimal('359.32'), Decimal('444.08'), Decimal('239.61'), Decimal('392.99'), Decimal('148.58'), Decimal('247.88'), Decimal('249.31'), Decimal('743.96'), Decimal('1790.14'), Decimal('228.95'), Decimal('210.81'), Decimal('373.32'), Decimal('261.28'), Decimal('141.58'), Decimal('243.99'), Decimal('108.99'), Decimal('107.66'), Decimal('274.99'), Decimal('67.06'), Decimal('74.99'), Decimal('150.08'), Decimal('644.99'), Decimal('231.66'), Decimal('209.00'), Decimal('349.00'), Decimal('772.26'), Decimal('555.23'), Decimal('293.62'), Decimal('247.99'), Decimal('139.95'), Decimal('629.63'), Decimal('122.42'), Decimal('265.54'), Decimal('495.53'), Decimal('431.09'), Decimal('176.77'), Decimal('151.16'), Decimal('99.98'), Decimal('422.14'), Decimal('178.57'), Decimal('278.01'), Decimal('162.33'), Decimal('192.00'), Decimal('89.99'), Decimal('148.70'), Decimal('250.46'), Decimal('117.50'), Decimal('156.02'), Decimal('182.58'), Decimal('564.97'), Decimal('199.47'), Decimal('199.96'), Decimal('143.34'), Decimal('276.48'), Decimal('158.57'), Decimal('402.99'), Decimal('239.99'), Decimal('157.64'), Decimal('177.54'), Decimal('285.16'), Decimal('126.54'), Decimal('127.99'), Decimal('85.00'), Decimal('154.65'), Decimal('219.87'), Decimal('275.94'), Decimal('67.76'), Decimal('121.96'), Decimal('713.00'), Decimal('209.55'), Decimal('8 ...

# %%
dict = {'Brand': brand, 'Name': name, 'Dim': Dimensions, 'Weight': Weight, 'Bat': Battery, 'Blue': Bluetooth, 'CPU': CPU, 
        'Cam': Camera, 'Cores': Cores, 'Dis': Display, 'GPU': GPU, 'Memory card': Memory_cards, 'OS': OS, 'Pos': Positioning, 
        'RAM': RAM, 'SIM': SIM_card, 'SoC': SoC, 'Storage': Storage, 'USB': USB, 'Wi-Fi': Wi_Fi, 'Average price': avg_price}
df = pd.DataFrame(dict)
df

# %%
df.to_csv (r'dataset.csv', index = None, header=True, sep = '\t')
